# %% [markdown]
# # getting started with pandas
#
# **Extra resources:**
#
# * Python Data Science Handbook: https://jakevdp.github.io/PythonDataScienceHandbook/
# * Pandas cheatsheet: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# <img src = "memes/pandas.PNG">

# %%
import numpy
import pandas

import seaborn
import matplotlib.pyplot as plt

import time
import sys
import os

import requests
from bs4 import BeautifulSoup
# Out:
# /Users/manuel/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
pandas.__version__
# Out:
# '1.0.3'

# %%
numpy.__version__
# Out:
# '1.17.2'

# %% [markdown]
# # dataframes, series and indexes

# %% [markdown]
# ### dataframes

# %% [markdown]
# Imagine them as excel tables that you can explore

# %%
pokemons = ["Bulbasaur", "Squirtle", "Charizard", "Pikachu", "Onix", "Geodude", "Vulpix", "Starmie"]
types = ["Grass / Poison", "Water", "Fire / Flying", "Electric", "Rock / Ground",  "Rock / Ground", "Fire", "Water"]
master = ["Ash", "Ash", "Ash", "Ash", "Brock", "Brock", "Misty", "Misty"]
pokedex_number = [1, 4, 7, 25, 95, 74, 37, 121]
evolved = ["No", "No", "Yes", "No", "No", "No", "No", "Yes"]

# %%
df_pokemon = pandas.DataFrame({"name": pokemons, 
                               "types": types, 
                               "master": master, 
                               "number": pokedex_number, 
                               "is_evolved": evolved})
df_pokemon
# Out:
#         name           types master  number is_evolved
# 0  Bulbasaur  Grass / Poison    Ash       1         No
# 1   Squirtle           Water    Ash       4         No
# 2  Charizard   Fire / Flying    Ash       7        Yes
# 3    Pikachu        Electric    Ash      25         No
# 4       Onix   Rock / Ground  Brock      95         No
# 5    Geodude   Rock / Ground  Brock      74         No
# 6     Vulpix            Fire  Misty      37         No
# 7    Starmie           Water  Misty     121        Yes

# %%
df_pokemon.values
# Out:
# array([['Bulbasaur', 'Grass / Poison', 'Ash', 1, 'No'],
#        ['Squirtle', 'Water', 'Ash', 4, 'No'],
#        ['Charizard', 'Fire / Flying', 'Ash', 7, 'Yes'],
#        ['Pikachu', 'Electric', 'Ash', 25, 'No'],
#        ['Onix', 'Rock / Ground', 'Brock', 95, 'No'],
#        ['Geodude', 'Rock / Ground', 'Brock', 74, 'No'],
#        ['Vulpix', 'Fire', 'Misty', 37, 'No'],
#        ['Starmie', 'Water', 'Misty', 121, 'Yes']], dtype=object)

# %%
type(df_pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
# pokemons = ["Bulbasaur", "Squirtle", "Charizard", "Pikachu", "Onix", "Geodude", "Vulpix", "Starmie"]
# types = ["Grass / Poison", "Water", "Fire / Flying", "Electric", "Rock / Ground",  "Rock / Ground", "Fire", "Water"]
# master = ["Ash", "Ash", "Ash", "Ash", "Brock", "Brock", "Misty"]
# pokedex_number = [1, 4, 7, 25, 95, 74, 37, 121]
# evolved = ["No", "No", "Yes", "No", "No", "No", "No", "Yes"]

# df_pokemon = pandas.DataFrame({"name": pokemons, 
#                                "types": types, 
#                                "master": master, 
#                                "number": pokedex_number, 
#                                "is_evolved": evolved})
# df_pokemon

# %% [markdown]
# ### Series

# %% [markdown]
# pandas columns are called Series

# %%
df_pokemon["name"]
# Out:
# 0    Bulbasaur
# 1     Squirtle
# 2    Charizard
# 3      Pikachu
# 4         Onix
# 5      Geodude
# 6       Vulpix
# 7      Starmie
# Name: name, dtype: object

# %%
type(df_pokemon["name"])
# Out:
# pandas.core.series.Series

# %%
df_pokemon["name"].values
# Out:
# array(['Bulbasaur', 'Squirtle', 'Charizard', 'Pikachu', 'Onix', 'Geodude',
#        'Vulpix', 'Starmie'], dtype=object)

# %% [markdown]
# Series (pandas columns) are  basically numpy arrays with a name on top. This means that you can apply numpy array operations to pandas columns

# %%
df_pokemon["name"].max()
# Out:
# 'Vulpix'

# %% [markdown]
# ### Indexes

# %%
df_pokemon
# Out:
#         name           types master  number is_evolved
# 0  Bulbasaur  Grass / Poison    Ash       1         No
# 1   Squirtle           Water    Ash       4         No
# 2  Charizard   Fire / Flying    Ash       7        Yes
# 3    Pikachu        Electric    Ash      25         No
# 4       Onix   Rock / Ground  Brock      95         No
# 5    Geodude   Rock / Ground  Brock      74         No
# 6     Vulpix            Fire  Misty      37         No
# 7    Starmie           Water  Misty     121        Yes

# %%
df_pokemon.columns
# Out:
# Index(['name', 'types', 'master', 'number', 'is_evolved'], dtype='object')

# %%
df_pokemon.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df_pokemon.loc[3, "master"]
# Out:
# 'Ash'

# %% [markdown]
# Indexes help us to acces individual values and slices of the dataframe

# %% [markdown]
# ### What can you do with a dataframe?

# %% [markdown]
# *Sort pokemon by pokedex number*

# %%
df_pokemon.sort_values(by = "number")
# Out:
#         name           types master  number is_evolved
# 0  Bulbasaur  Grass / Poison    Ash       1         No
# 1   Squirtle           Water    Ash       4         No
# 2  Charizard   Fire / Flying    Ash       7        Yes
# 3    Pikachu        Electric    Ash      25         No
# 6     Vulpix            Fire  Misty      37         No
# 5    Geodude   Rock / Ground  Brock      74         No
# 4       Onix   Rock / Ground  Brock      95         No
# 7    Starmie           Water  Misty     121        Yes

# %% [markdown]
# *Which pokemon are evolved?*

# %%
df_pokemon.loc[df_pokemon["is_evolved"] == "Yes"]
# Out:
#         name          types master  number is_evolved
# 2  Charizard  Fire / Flying    Ash       7        Yes
# 7    Starmie          Water  Misty     121        Yes

# %% [markdown]
# *Which pokemon are dual type?*

# %%
df_pokemon["is_dual_type"] = df_pokemon["types"].str.contains("/")
df_pokemon
# Out:
#         name           types master  number is_evolved  is_dual_type
# 0  Bulbasaur  Grass / Poison    Ash       1         No          True
# 1   Squirtle           Water    Ash       4         No         False
# 2  Charizard   Fire / Flying    Ash       7        Yes          True
# 3    Pikachu        Electric    Ash      25         No         False
# 4       Onix   Rock / Ground  Brock      95         No          True
# 5    Geodude   Rock / Ground  Brock      74         No          True
# 6     Vulpix            Fire  Misty      37         No         False
# 7    Starmie           Water  Misty     121        Yes         False

# %%
df_pokemon.loc[df_pokemon["is_dual_type"]]
# Out:
#         name           types master  number is_evolved  is_dual_type
# 0  Bulbasaur  Grass / Poison    Ash       1         No          True
# 2  Charizard   Fire / Flying    Ash       7        Yes          True
# 4       Onix   Rock / Ground  Brock      95         No          True
# 5    Geodude   Rock / Ground  Brock      74         No          True

# %% [markdown]
# *Add a region column*

# %%
df_pokemon["region"] = "Kanto"
df_pokemon
# Out:
#         name           types master  number is_evolved  is_dual_type region
# 0  Bulbasaur  Grass / Poison    Ash       1         No          True  Kanto
# 1   Squirtle           Water    Ash       4         No         False  Kanto
# 2  Charizard   Fire / Flying    Ash       7        Yes          True  Kanto
# 3    Pikachu        Electric    Ash      25         No         False  Kanto
# 4       Onix   Rock / Ground  Brock      95         No          True  Kanto
# 5    Geodude   Rock / Ground  Brock      74         No          True  Kanto
# 6     Vulpix            Fire  Misty      37         No         False  Kanto
# 7    Starmie           Water  Misty     121        Yes         False  Kanto

# %% [markdown]
# *Add a new row*

# %%
df_pokemon.loc[len(df_pokemon)] = ["Togepi", "Normal", "Misty", None, "No", "No", "Johto"]
df_pokemon
# Out:
#         name           types master number is_evolved is_dual_type region
# 0  Bulbasaur  Grass / Poison    Ash      1         No         True  Kanto
# 1   Squirtle           Water    Ash      4         No        False  Kanto
# 2  Charizard   Fire / Flying    Ash      7        Yes         True  Kanto
# 3    Pikachu        Electric    Ash     25         No        False  Kanto
# 4       Onix   Rock / Ground  Brock     95         No         True  Kanto
# 5    Geodude   Rock / Ground  Brock     74         No         True  Kanto
# 6     Vulpix            Fire  Misty     37         No        False  Kanto
# 7    Starmie           Water  Misty    121        Yes        False  Kanto
# 8     Togepi          Normal  Misty   None         No           No  Johto

# %% [markdown]
# *Fill Togepi pokedex number*

# %%
df_pokemon.loc[df_pokemon["name"] == "Togepi", "number"] = 175
df_pokemon
# Out:
#         name           types master number is_evolved is_dual_type region
# 0  Bulbasaur  Grass / Poison    Ash      1         No         True  Kanto
# 1   Squirtle           Water    Ash      4         No        False  Kanto
# 2  Charizard   Fire / Flying    Ash      7        Yes         True  Kanto
# 3    Pikachu        Electric    Ash     25         No        False  Kanto
# 4       Onix   Rock / Ground  Brock     95         No         True  Kanto
# 5    Geodude   Rock / Ground  Brock     74         No         True  Kanto
# 6     Vulpix            Fire  Misty     37         No        False  Kanto
# 7    Starmie           Water  Misty    121        Yes        False  Kanto
# 8     Togepi          Normal  Misty    175         No           No  Johto

# %% [markdown]
# # Pandas foundations

# %%
os.listdir("data")
# Out:
# ['lego_sets.csv', 'cards.collectible.json', '.DS_Store']

# %% [markdown]
# ## Lego dataset (reading flat files)

# %%
df_legos = pandas.read_csv("data/lego_sets.csv")
df_legos.head()
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %%
len(df_legos)
# Out:
# 12261

# %%
df_legos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ages               12261 non-null  object
#  1   list_price         12261 non-null  float64
#  2   num_reviews        10641 non-null  float64
#  3   piece_count        12261 non-null  float64
#  4   play_star_rating   10486 non-null  float64
#  5   prod_desc          11884 non-null  object
#  6   prod_id            12261 non-null  float64
#  7   prod_long_desc     12261 non-null  object
#  8   review_difficulty  10206 non-null  object
#  9   set_name           12261 non-null  object
#  10  star_rating        10641 non-null  float64
#  11  theme_name         12258 non-null  object
#  12  val_star_rating    10466 non-null  float64
#  13  country            12261 non-null  object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB

# %%
df_legos.describe()
# Out:
#          list_price   num_reviews   piece_count  play_star_rating  \
# count  12261.000000  10641.000000  12261.000000      10486.000000
# mean      65.141998     16.826238    493.405921          4.337641
# std       91.980429     36.368984    825.364580          0.652051
# min        2.272400      1.000000      1.000000          1.000000
# 25%       19.990000      2.000000     97.000000          4.000000
# 50%       36.587800      6.000000    216.000000          4.500000
# 75%       70.192200     13.000000    544.000000          4.800000
# max     1104.870000    367.000000   7541.000000          5.000000
#
#             prod_id   star_rating  val_star_rating
# count  1.226100e+04  10641.000000     10466.000000
# mean   5.983675e+04      4.514134         4.228960
# std    1.638115e+05      0.518865         0.660282
# min    6.300000e+02      1.800000         1.000000
# 25%    2.103400e+04      4.300000         4.000000
# 50%    4.206900e+04      4.700000         4.300000
# 75%    7.092200e+04      5.000000         4.700000
# max    2.000431e+06      5.000000         5.000000

# %%
df_legos = df_legos.dropna()
df_legos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9910 entries, 0 to 12260
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ages               9910 non-null   object
#  1   list_price         9910 non-null   float64
#  2   num_reviews        9910 non-null   float64
#  3   piece_count        9910 non-null   float64
#  4   play_star_rating   9910 non-null   float64
#  5   prod_desc          9910 non-null   object
#  6   prod_id            9910 non-null   float64
#  7   prod_long_desc     9910 non-null   object
#  8   review_difficulty  9910 non-null   object
#  9   set_name           9910 non-null   object
#  10  star_rating        9910 non-null   float64
#  11  theme_name         9910 non-null   object
#  12  val_star_rating    9910 non-null   float64
#  13  country            9910 non-null   object
# dtypes: float64(7), object(7)
# memory usage: 1.1+ MB

# %%
df_legos = df_legos.drop(["prod_id", "prod_long_desc", "num_reviews", "val_star_rating"], axis = 1)
df_legos.head()
# Out:
#    ages  list_price  piece_count  play_star_rating  \
# 0  6-12       29.99        277.0               4.0
# 1  6-12       19.99        168.0               4.0
# 2  6-12       12.99         74.0               4.3
# 3   12+       99.99       1032.0               3.6
# 4   12+       79.99        744.0               3.2
#
#                                            prod_desc review_difficulty  \
# 0  Catapult into action and take back the eggs fr...           Average
# 1  Launch a flying attack and rescue the eggs fro...              Easy
# 2  Chase the piggy with lightning-fast Chuck and ...              Easy
# 3  Explore the architecture of the United States ...           Average
# 4  Recreate the Solomon R. Guggenheim Museum® wit...       Challenging
#
#                          set_name  star_rating    theme_name country
# 0           Bird Island Egg Heist          4.5  Angry Birds™      US
# 1              Piggy Plane Attack          5.0  Angry Birds™      US
# 2                Piggy Car Escape          4.3  Angry Birds™      US
# 3  United States Capitol Building          4.6  Architecture      US
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture      US

# %% [markdown]
# ## Are there any marvel lego pieces with easy difficulty that cost less than 150 dollars? (row and column selection)

# %% [markdown]
# *how many difficulty levels there are?*

# %%
df_legos["review_difficulty"].unique()
# Out:
# array(['Average', 'Easy', 'Challenging', 'Very Easy', 'Very Challenging'],
#       dtype=object)

# %%
df_legos["review_difficulty"].nunique()
# Out:
# 5

# %%
df_legos["theme_name"].unique()
# Out:
# array(['Angry Birds™', 'Architecture', 'BOOST', 'BrickHeadz', 'City',
#        'Classic', 'Creator 3-in-1', 'Creator Expert',
#        'THE LEGO® BATMAN MOVIE', 'DC Comics™ Super Heroes', 'DIMENSIONS™',
#        'Juniors', 'DC Super Hero Girls', 'Disney™', 'DUPLO®', 'Elves',
#        'Friends', 'Ghostbusters™', 'Ideas',
#        'Indoraptor Rampage at Lockwood Estate',
#        'Jurassic Park Velociraptor Chase', 'Dilophosaurus Outpost Attack',
#        'Stygimoloch Breakout', 'Pteranodon Chase', 'Marvel Super Heroes',
#        'MINDSTORMS®', 'Minecraft™', 'Minifigures', 'NEXO KNIGHTS™',
#        'THE LEGO® NINJAGO® MOVIE™', 'NINJAGO®', 'Speed Champions',
#        'Star Wars™', 'Technic', 'Power Functions',
#        'Carnotaurus Gyrosphere Escape', 'LEGO® Creator 3-in-1'],
#       dtype=object)

# %%
df_legos["theme_name"].nunique()
# Out:
# 37

# %% [markdown]
# ### Column selection

# %%
df_legos_mini = df_legos[["set_name", "theme_name", "ages", "piece_count", "review_difficulty", "country"]] 
df_legos_mini
# Out:
#                              set_name                 theme_name  ages  \
# 0               Bird Island Egg Heist               Angry Birds™  6-12
# 1                  Piggy Plane Attack               Angry Birds™  6-12
# 2                    Piggy Car Escape               Angry Birds™  6-12
# 3      United States Capitol Building               Architecture   12+
# 4       Solomon R. Guggenheim Museum®               Architecture   12+
# ...                               ...                        ...   ...
# 12256                Manta Ray Bomber  THE LEGO® NINJAGO® MOVIE™  7-14
# 12257                  Piranha Attack  THE LEGO® NINJAGO® MOVIE™  7-14
# 12258             NINJAGO® City Chase  THE LEGO® NINJAGO® MOVIE™  7-14
# 12259        Lloyd - Spinjitzu Master  THE LEGO® NINJAGO® MOVIE™  6-14
# 12260              Spinjitzu Training  THE LEGO® NINJAGO® MOVIE™  6-14
#
#        piece_count review_difficulty country
# 0            277.0           Average      US
# 1            168.0              Easy      US
# 2             74.0              Easy      US
# 3           1032.0           Average      US
# 4            744.0       Challenging      US
# ...            ...               ...     ...
# 12256        341.0              Easy      PT
# 12257        217.0              Easy      PT
# 12258        233.0              Easy      PT
# 12259         48.0         Very Easy      PT
# 12260        109.0              Easy      PT
#
# [9910 rows x 6 columns]

# %% [markdown]
# ### Row selection

# %%
df_legos_mini.loc[df_legos_mini["piece_count"] > 500]
# Out:
#                              set_name                 theme_name  ages  \
# 3      United States Capitol Building               Architecture   12+
# 4       Solomon R. Guggenheim Museum®               Architecture   12+
# 5                            Shanghai               Architecture   12+
# 6                       New York City               Architecture   12+
# 7                   Buckingham Palace               Architecture   12+
# ...                               ...                        ...   ...
# 12248                       Fire Mech  THE LEGO® NINJAGO® MOVIE™  9-14
# 12249                   Lightning Jet  THE LEGO® NINJAGO® MOVIE™  9-14
# 12250                 Garma Mecha Man  THE LEGO® NINJAGO® MOVIE™  8-14
# 12251         Garmadon's Volcano Lair  THE LEGO® NINJAGO® MOVIE™  8-14
# 12252         Green Ninja Mech Dragon  THE LEGO® NINJAGO® MOVIE™  8-14
#
#        piece_count review_difficulty country
# 3           1032.0           Average      US
# 4            744.0       Challenging      US
# 5            597.0           Average      US
# 6            598.0           Average      US
# 7            780.0           Average      US
# ...            ...               ...     ...
# 12248        944.0           Average      PT
# 12249        876.0           Average      PT
# 12250        747.0           Average      PT
# 12251        521.0           Average      PT
# 12252        544.0           Average      PT
#
# [2954 rows x 6 columns]

# %% [markdown]
# ### Combined selection

# %%
df_legos_mini_double = df_legos_mini.loc[df_legos_mini["theme_name"].str.contains("Star Wars"), 
                                         ["set_name", "theme_name"]]
df_legos_mini_double
# Out:
#                                     set_name  theme_name
# 628            Kessel Run Millennium Falcon™  Star Wars™
# 629                    Imperial TIE Fighter™  Star Wars™
# 630                    Moloch's Landspeeder™  Star Wars™
# 631                               Yoda's Hut  Star Wars™
# 632                  Han Solo's Landspeeder™  Star Wars™
# ...                                      ...         ...
# 12192                             Yoda's Hut  Star Wars™
# 12193  Jedi™ and Clone Troopers™ Battle Pack  Star Wars™
# 12194            Imperial Patrol Battle Pack  Star Wars™
# 12195                    A-Wing Starfighter™  Star Wars™
# 12197                     Millennium Falcon™  Star Wars™
#
# [1322 rows x 2 columns]

# %%
#example of str contains

# %% [markdown]
# *Answering the original question*

# %%
df_legos[["set_name", "theme_name", "list_price"]]\
        .loc[df_legos["theme_name"] == "Marvel Super Heroes"]\
        .loc[df_legos["review_difficulty"] == "Easy"]\
        .loc[df_legos["list_price"] <= 150]
# Out:
#                               set_name           theme_name  list_price
# 467            The Hulkbuster Smash-Up  Marvel Super Heroes     29.9900
# 468                Thor's Weapon Quest  Marvel Super Heroes     19.9900
# 469           Outrider Dropship Attack  Marvel Super Heroes     14.9900
# 475                  Hulk vs. Red Hulk  Marvel Super Heroes     59.9900
# 476     The Ultimate Battle for Asgard  Marvel Super Heroes     49.9900
# ...                                ...                  ...         ...
# 12038  Iron Man: Detroit Steel Strikes  Marvel Super Heroes     47.5678
# 12039       Rhino Face-Off by the Mine  Marvel Super Heroes     36.5878
# 12041                 ATM Heist Battle  Marvel Super Heroes     35.3678
# 12042      Captain America Jet Pursuit  Marvel Super Heroes     35.3678
# 12044     Mighty Micros: Thor vs. Loki  Marvel Super Heroes     12.1878
#
# [215 rows x 3 columns]

# %%
df_legos.loc[(df_legos["theme_name"] == "Marvel Super Heroes") & 
             (df_legos["review_difficulty"] == "Easy") &
             (df_legos["list_price"] <= 150), ["set_name", "theme_name", "list_price"]]
# Out:
#                               set_name           theme_name  list_price
# 467            The Hulkbuster Smash-Up  Marvel Super Heroes     29.9900
# 468                Thor's Weapon Quest  Marvel Super Heroes     19.9900
# 469           Outrider Dropship Attack  Marvel Super Heroes     14.9900
# 475                  Hulk vs. Red Hulk  Marvel Super Heroes     59.9900
# 476     The Ultimate Battle for Asgard  Marvel Super Heroes     49.9900
# ...                                ...                  ...         ...
# 12038  Iron Man: Detroit Steel Strikes  Marvel Super Heroes     47.5678
# 12039       Rhino Face-Off by the Mine  Marvel Super Heroes     36.5878
# 12041                 ATM Heist Battle  Marvel Super Heroes     35.3678
# 12042      Captain America Jet Pursuit  Marvel Super Heroes     35.3678
# 12044     Mighty Micros: Thor vs. Loki  Marvel Super Heroes     12.1878
#
# [215 rows x 3 columns]

# %% [markdown]
# ## Whats the brand of the toys? (broadcasting)

# %%
df_legos_aux = df_legos[["set_name", "theme_name"]].copy()
df_legos_aux.head(10)
# Out:
#                          set_name    theme_name
# 0           Bird Island Egg Heist  Angry Birds™
# 1              Piggy Plane Attack  Angry Birds™
# 2                Piggy Car Escape  Angry Birds™
# 3  United States Capitol Building  Architecture
# 4   Solomon R. Guggenheim Museum®  Architecture
# 5                        Shanghai  Architecture
# 6                   New York City  Architecture
# 7               Buckingham Palace  Architecture
# 8                          London  Architecture
# 9                         Chicago  Architecture

# %%
df_legos_aux["brand"] = "Lego"
df_legos_aux
# Out:
#                              set_name                 theme_name brand
# 0               Bird Island Egg Heist               Angry Birds™  Lego
# 1                  Piggy Plane Attack               Angry Birds™  Lego
# 2                    Piggy Car Escape               Angry Birds™  Lego
# 3      United States Capitol Building               Architecture  Lego
# 4       Solomon R. Guggenheim Museum®               Architecture  Lego
# ...                               ...                        ...   ...
# 12256                Manta Ray Bomber  THE LEGO® NINJAGO® MOVIE™  Lego
# 12257                  Piranha Attack  THE LEGO® NINJAGO® MOVIE™  Lego
# 12258             NINJAGO® City Chase  THE LEGO® NINJAGO® MOVIE™  Lego
# 12259        Lloyd - Spinjitzu Master  THE LEGO® NINJAGO® MOVIE™  Lego
# 12260              Spinjitzu Training  THE LEGO® NINJAGO® MOVIE™  Lego
#
# [9910 rows x 3 columns]

# %% [markdown]
# *Reordering columns*

# %%
df_legos_aux[["brand", "theme_name", "set_name"]]
# Out:
#       brand                 theme_name                        set_name
# 0      Lego               Angry Birds™           Bird Island Egg Heist
# 1      Lego               Angry Birds™              Piggy Plane Attack
# 2      Lego               Angry Birds™                Piggy Car Escape
# 3      Lego               Architecture  United States Capitol Building
# 4      Lego               Architecture   Solomon R. Guggenheim Museum®
# ...     ...                        ...                             ...
# 12256  Lego  THE LEGO® NINJAGO® MOVIE™                Manta Ray Bomber
# 12257  Lego  THE LEGO® NINJAGO® MOVIE™                  Piranha Attack
# 12258  Lego  THE LEGO® NINJAGO® MOVIE™             NINJAGO® City Chase
# 12259  Lego  THE LEGO® NINJAGO® MOVIE™        Lloyd - Spinjitzu Master
# 12260  Lego  THE LEGO® NINJAGO® MOVIE™              Spinjitzu Training
#
# [9910 rows x 3 columns]

# %% [markdown]
# ## What architecture lego are more difficult and have more pieces? (sorting)

# %%
df_legos_architecture = df_legos.loc[df_legos["theme_name"] == "Architecture"]
df_legos_architecture.head(3)
# Out:
#   ages  list_price  piece_count  play_star_rating  \
# 3  12+       99.99       1032.0               3.6
# 4  12+       79.99        744.0               3.2
# 5  12+       59.99        597.0               3.7
#
#                                            prod_desc review_difficulty  \
# 3  Explore the architecture of the United States ...           Average
# 4  Recreate the Solomon R. Guggenheim Museum® wit...       Challenging
# 5  Celebrate Shanghai with this LEGO® Architectur...           Average
#
#                          set_name  star_rating    theme_name country
# 3  United States Capitol Building          4.6  Architecture      US
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture      US
# 5                        Shanghai          4.9  Architecture      US

# %%
df_legos_architecture.sort_values(by = "review_difficulty").head(5)
# Out:
#      ages  list_price  piece_count  play_star_rating  \
# 3     12+     99.9900       1032.0               3.6
# 7256  12+     62.9860        598.0               3.7
# 7257  12+     41.9860        321.0               3.2
# 7258  12+     41.9860        386.0               4.1
# 7826  12+    134.1878       1032.0               3.6
#
#                                               prod_desc review_difficulty  \
# 3     Explore the architecture of the United States ...           Average
# 7256  Celebrate New York City with this LEGO® Archit...           Average
# 7257  Build your own LEGO® interpretation of the ico...           Average
# 7258    Experience the grandeur of the Arc de Triomphe!           Average
# 7826  Explore the architecture of the United States ...           Average
#
#                             set_name  star_rating    theme_name country
# 3     United States Capitol Building          4.6  Architecture      US
# 7256                   New York City          4.2  Architecture      GB
# 7257                The Eiffel Tower          4.6  Architecture      GB
# 7258                 Arc de Triomphe          4.4  Architecture      GB
# 7826  United States Capitol Building          4.6  Architecture      IE

# %%
df_legos_architecture = df_legos.get(["set_name", "theme_name", "piece_count", "review_difficulty"])\
                                .loc[df_legos["theme_name"] == "Architecture"]
df_legos_architecture = df_legos_architecture.drop_duplicates()
df_legos_architecture
# Out:
#                           set_name    theme_name  piece_count  \
# 3   United States Capitol Building  Architecture       1032.0
# 4    Solomon R. Guggenheim Museum®  Architecture        744.0
# 5                         Shanghai  Architecture        597.0
# 6                    New York City  Architecture        598.0
# 7                Buckingham Palace  Architecture        780.0
# 8                           London  Architecture        468.0
# 9                          Chicago  Architecture        444.0
# 10                 Arc de Triomphe  Architecture        386.0
# 11                The Eiffel Tower  Architecture        321.0
# 12                          Sydney  Architecture        361.0
#
#    review_difficulty
# 3            Average
# 4        Challenging
# 5            Average
# 6            Average
# 7            Average
# 8            Average
# 9            Average
# 10           Average
# 11           Average
# 12              Easy

# %%
df_legos_architecture.sort_values(by = "piece_count")
# Out:
#                           set_name    theme_name  piece_count  \
# 11                The Eiffel Tower  Architecture        321.0
# 12                          Sydney  Architecture        361.0
# 10                 Arc de Triomphe  Architecture        386.0
# 9                          Chicago  Architecture        444.0
# 8                           London  Architecture        468.0
# 5                         Shanghai  Architecture        597.0
# 6                    New York City  Architecture        598.0
# 4    Solomon R. Guggenheim Museum®  Architecture        744.0
# 7                Buckingham Palace  Architecture        780.0
# 3   United States Capitol Building  Architecture       1032.0
#
#    review_difficulty
# 11           Average
# 12              Easy
# 10           Average
# 9            Average
# 8            Average
# 5            Average
# 6            Average
# 4        Challenging
# 7            Average
# 3            Average

# %%
df_legos_architecture.sort_values(by = "piece_count", ascending = False)
# Out:
#                           set_name    theme_name  piece_count  \
# 3   United States Capitol Building  Architecture       1032.0
# 7                Buckingham Palace  Architecture        780.0
# 4    Solomon R. Guggenheim Museum®  Architecture        744.0
# 6                    New York City  Architecture        598.0
# 5                         Shanghai  Architecture        597.0
# 8                           London  Architecture        468.0
# 9                          Chicago  Architecture        444.0
# 10                 Arc de Triomphe  Architecture        386.0
# 12                          Sydney  Architecture        361.0
# 11                The Eiffel Tower  Architecture        321.0
#
#    review_difficulty
# 3            Average
# 7            Average
# 4        Challenging
# 6            Average
# 5            Average
# 8            Average
# 9            Average
# 10           Average
# 12              Easy
# 11           Average

# %%
df_legos_architecture.sort_values(by = ["review_difficulty", "piece_count"])
# Out:
#                           set_name    theme_name  piece_count  \
# 11                The Eiffel Tower  Architecture        321.0
# 10                 Arc de Triomphe  Architecture        386.0
# 9                          Chicago  Architecture        444.0
# 8                           London  Architecture        468.0
# 5                         Shanghai  Architecture        597.0
# 6                    New York City  Architecture        598.0
# 7                Buckingham Palace  Architecture        780.0
# 3   United States Capitol Building  Architecture       1032.0
# 4    Solomon R. Guggenheim Museum®  Architecture        744.0
# 12                          Sydney  Architecture        361.0
#
#    review_difficulty
# 11           Average
# 10           Average
# 9            Average
# 8            Average
# 5            Average
# 6            Average
# 7            Average
# 3            Average
# 4        Challenging
# 12              Easy

# %%
df_legos_architecture["review_difficulty"] = pandas.Categorical(df_legos_architecture["review_difficulty"], 
                                        categories=['Very Easy', 'Easy', 'Average', 'Challenging', 'Very Challenging'],
                                        ordered = True)

# %%
df_legos_architecture.sort_values(by = ["review_difficulty", "piece_count"])
# Out:
#                           set_name    theme_name  piece_count  \
# 12                          Sydney  Architecture        361.0
# 11                The Eiffel Tower  Architecture        321.0
# 10                 Arc de Triomphe  Architecture        386.0
# 9                          Chicago  Architecture        444.0
# 8                           London  Architecture        468.0
# 5                         Shanghai  Architecture        597.0
# 6                    New York City  Architecture        598.0
# 7                Buckingham Palace  Architecture        780.0
# 3   United States Capitol Building  Architecture       1032.0
# 4    Solomon R. Guggenheim Museum®  Architecture        744.0
#
#    review_difficulty
# 12              Easy
# 11           Average
# 10           Average
# 9            Average
# 8            Average
# 5            Average
# 6            Average
# 7            Average
# 3            Average
# 4        Challenging

# %% [markdown]
# # Making a pokedex (reading html code)

# %% [markdown]
# What if I don't have a csv? We have information available online. Pandas helps with the scrapping of tables in html  or xml format.
#
# * `pandas.read_html` https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.read_html.html
# * Pokedex database: https://pokemondb.net/pokedex/all

# %%
url_database = "https://pokemondb.net/pokedex/all"
html_text = requests.get(url_database).content

pandas.read_html(html_text)
# Out:
# [        #                         Name            Type  Total   HP  Attack  \
#  0       1                    Bulbasaur    Grass Poison    318   45      49
#  1       2                      Ivysaur    Grass Poison    405   60      62
#  2       3                     Venusaur    Grass Poison    525   80      82
#  3       3       Venusaur Mega Venusaur    Grass Poison    625   80     100
#  4       4                   Charmander            Fire    309   39      52
#  ...   ...                          ...             ...    ...  ...     ...
#  1029  890          Eternatus Eternamax   Poison Dragon   1125  255     115
#  1030  891                        Kubfu        Fighting    385   60      90
#  1031  892  Urshifu Single Strike Style   Fighting Dark    550  100     130
#  1032  892   Urshifu Rapid Strike Style  Fighting Water    550  100     130
#  1033  893                       Zarude      Dark Grass    600  105     120
#
#        Defense  Sp. Atk  Sp. Def  Speed
#  0          49       65       65     45
#  1          63       80       80     60
#  2          83      100      100     80
#  3         123      122      120     80
#  4          43       60       50     65
#  ...       ...      ...      ...    ...
#  1029      250      125      250    130
#  1030       60       53       50     72
#  1031      100       63       60     97
#  1032      100       63       60     97
#  1033      105       70       95    105
#
#  [1034 rows x 10 columns]]

# %%
df_pokedex = pandas.read_html(html_text)[0]
df_pokedex.head()
# Out:
#    #                    Name          Type  Total  HP  Attack  Defense  \
# 0  1               Bulbasaur  Grass Poison    318  45      49       49
# 1  2                 Ivysaur  Grass Poison    405  60      62       63
# 2  3                Venusaur  Grass Poison    525  80      82       83
# 3  3  Venusaur Mega Venusaur  Grass Poison    625  80     100      123
# 4  4              Charmander          Fire    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed
# 0       65       65     45
# 1       80       80     60
# 2      100      100     80
# 3      122      120     80
# 4       60       50     65

# %% [markdown]
# ## Create a separate type 1 and type 2 columns for pokemons

# %%
split_columns = df_pokedex["Type"].str.split(" ", expand = True)

df_pokedex["Type 1"] = split_columns[0]
df_pokedex["Type 2"] = split_columns[1]
df_pokedex
# Out:
#         #                         Name            Type  Total   HP  Attack  \
# 0       1                    Bulbasaur    Grass Poison    318   45      49
# 1       2                      Ivysaur    Grass Poison    405   60      62
# 2       3                     Venusaur    Grass Poison    525   80      82
# 3       3       Venusaur Mega Venusaur    Grass Poison    625   80     100
# 4       4                   Charmander            Fire    309   39      52
# ...   ...                          ...             ...    ...  ...     ...
# 1029  890          Eternatus Eternamax   Poison Dragon   1125  255     115
# 1030  891                        Kubfu        Fighting    385   60      90
# 1031  892  Urshifu Single Strike Style   Fighting Dark    550  100     130
# 1032  892   Urshifu Rapid Strike Style  Fighting Water    550  100     130
# 1033  893                       Zarude      Dark Grass    600  105     120
#
#       Defense  Sp. Atk  Sp. Def  Speed    Type 1  Type 2
# 0          49       65       65     45     Grass  Poison
# 1          63       80       80     60     Grass  Poison
# 2          83      100      100     80     Grass  Poison
# 3         123      122      120     80     Grass  Poison
# 4          43       60       50     65      Fire    None
# ...       ...      ...      ...    ...       ...     ...
# 1029      250      125      250    130    Poison  Dragon
# 1030       60       53       50     72  Fighting    None
# 1031      100       63       60     97  Fighting    Dark
# 1032      100       63       60     97  Fighting   Water
# 1033      105       70       95    105      Dark   Grass
#
# [1034 rows x 12 columns]

# %% [markdown]
# ## What's the strongest physical attacker?

# %%
df_pokedex.sort_values(by = ["Attack"], ascending = False)
# Out:
#        #                      Name              Type  Total   HP  Attack  \
# 191  150      Mewtwo Mega Mewtwo X  Psychic Fighting    780  106     190
# 260  214  Heracross Mega Heracross      Bug Fighting    600   80     185
# 927  798                   Kartana       Grass Steel    570   59     181
# 458  383    Groudon Primal Groudon       Ground Fire    770  100     180
# 460  384    Rayquaza Mega Rayquaza     Dragon Flying    780  105     180
# ..   ...                       ...               ...    ...  ...     ...
# 290  242                   Blissey            Normal    540  255      10
# 258  213                   Shuckle          Bug Rock    505   20      10
# 166  129                  Magikarp             Water    200   20      10
# 147  113                   Chansey            Normal    450  250       5
# 522  440                   Happiny            Normal    220  100       5
#
#      Defense  Sp. Atk  Sp. Def  Speed   Type 1    Type 2
# 191      100      154      100    130  Psychic  Fighting
# 260      115       40      105     75      Bug  Fighting
# 927      131       59       31    109    Grass     Steel
# 458      160      150       90     90   Ground      Fire
# 460      100      180      100    115   Dragon    Flying
# ..       ...      ...      ...    ...      ...       ...
# 290       10       75      135     55   Normal      None
# 258      230       10      230      5      Bug      Rock
# 166       55       15       20     80    Water      None
# 147        5       35      105     50   Normal      None
# 522        5       15       65     30   Normal      None
#
# [1034 rows x 12 columns]

# %% [markdown]
# ## What's the strongest special attacker?

# %%
df_pokedex.sort_values(by = ["Sp. Atk"], ascending = False)
# Out:
#        #                        Name           Type  Total   HP  Attack  \
# 192  150        Mewtwo Mega Mewtwo Y        Psychic    780  106     150
# 463  386         Deoxys Attack Forme        Psychic    600   50     180
# 460  384      Rayquaza Mega Rayquaza  Dragon Flying    780  105     180
# 456  382        Kyogre Primal Kyogre          Water    770  100     150
# 84    65      Alakazam Mega Alakazam        Psychic    600   55      50
# ..   ...                         ...            ...    ...  ...     ...
# 522  440                     Happiny         Normal    220  100       5
# 412  349                      Feebas          Water    200   20      15
# 37    27  Sandshrew Alolan Sandshrew      Ice Steel    300   50      75
# 520  438                      Bonsly           Rock    290   50      80
# 258  213                     Shuckle       Bug Rock    505   20      10
#
#      Defense  Sp. Atk  Sp. Def  Speed   Type 1  Type 2
# 192       70      194      120    140  Psychic    None
# 463       20      180       20    150  Psychic    None
# 460      100      180      100    115   Dragon  Flying
# 456       90      180      160     90    Water    None
# 84        65      175      105    150  Psychic    None
# ..       ...      ...      ...    ...      ...     ...
# 522        5       15       65     30   Normal    None
# 412       20       10       55     80    Water    None
# 37        90       10       35     40      Ice   Steel
# 520       95       10       45     10     Rock    None
# 258      230       10      230      5      Bug    Rock
#
# [1034 rows x 12 columns]

# %% [markdown]
# ## Rename # column

# %%
df_pokedex = df_pokedex.rename(columns = {"#": "Pokedex"})
df_pokedex
# Out:
#       Pokedex                         Name            Type  Total   HP  \
# 0           1                    Bulbasaur    Grass Poison    318   45
# 1           2                      Ivysaur    Grass Poison    405   60
# 2           3                     Venusaur    Grass Poison    525   80
# 3           3       Venusaur Mega Venusaur    Grass Poison    625   80
# 4           4                   Charmander            Fire    309   39
# ...       ...                          ...             ...    ...  ...
# 1029      890          Eternatus Eternamax   Poison Dragon   1125  255
# 1030      891                        Kubfu        Fighting    385   60
# 1031      892  Urshifu Single Strike Style   Fighting Dark    550  100
# 1032      892   Urshifu Rapid Strike Style  Fighting Water    550  100
# 1033      893                       Zarude      Dark Grass    600  105
#
#       Attack  Defense  Sp. Atk  Sp. Def  Speed    Type 1  Type 2
# 0         49       49       65       65     45     Grass  Poison
# 1         62       63       80       80     60     Grass  Poison
# 2         82       83      100      100     80     Grass  Poison
# 3        100      123      122      120     80     Grass  Poison
# 4         52       43       60       50     65      Fire    None
# ...      ...      ...      ...      ...    ...       ...     ...
# 1029     115      250      125      250    130    Poison  Dragon
# 1030      90       60       53       50     72  Fighting    None
# 1031     130      100       63       60     97  Fighting    Dark
# 1032     130      100       63       60     97  Fighting   Water
# 1033     120      105       70       95    105      Dark   Grass
#
# [1034 rows x 12 columns]

# %% [markdown]
# ## What's the fastest pokemon of the first generation?

# %%
df_pokedex.loc[df_pokedex["Pokedex"] <= 151].sort_values(by = "Speed", ascending = False)
# Out:
#      Pokedex                        Name           Type  Total   HP  Attack  \
# 84        65      Alakazam Mega Alakazam        Psychic    600   55      50
# 182      142  Aerodactyl Mega Aerodactyl    Rock Flying    615   80     135
# 132      101                   Electrode       Electric    490   60      50
# 19        15      Beedrill Mega Beedrill     Bug Poison    495   65     150
# 192      150        Mewtwo Mega Mewtwo Y        Psychic    780  106     150
# ..       ...                         ...            ...    ...  ...     ...
# 52        39                  Jigglypuff   Normal Fairy    270  115      45
# 94        74      Geodude Alolan Geodude  Rock Electric    300   40      80
# 93        74                     Geodude    Rock Ground    300   40      80
# 104       79  Slowpoke Galarian Slowpoke        Psychic    315   90      65
# 103       79                    Slowpoke  Water Psychic    315   90      65
#
#      Defense  Sp. Atk  Sp. Def  Speed    Type 1    Type 2
# 84        65      175      105    150   Psychic      None
# 182       85       70       95    150      Rock    Flying
# 132       70       80       80    150  Electric      None
# 19        40       15       80    145       Bug    Poison
# 192       70      194      120    140   Psychic      None
# ..       ...      ...      ...    ...       ...       ...
# 52        20       45       25     20    Normal     Fairy
# 94       100       30       30     20      Rock  Electric
# 93       100       30       30     20      Rock    Ground
# 104       65       40       40     15   Psychic      None
# 103       65       40       40     15     Water   Psychic
#
# [194 rows x 12 columns]

# %% [markdown]
# ## What's the fastest pokemon of the first generation? (no megas)

# %%
df_pokedex.loc[(df_pokedex["Pokedex"] <= 151) & (~df_pokedex["Name"].str.contains("Mega"))]\
            .sort_values(by = "Speed", ascending = False)
# Out:
#      Pokedex                        Name           Type  Total   HP  Attack  \
# 132      101                   Electrode       Electric    490   60      50
# 181      142                  Aerodactyl    Rock Flying    515   80     105
# 174      135                     Jolteon       Electric    525   65      65
# 190      150                      Mewtwo        Psychic    680  106     110
# 33        25     Pikachu Partner Pikachu       Electric    430   45      80
# ..       ...                         ...            ...    ...  ...     ...
# 52        39                  Jigglypuff   Normal Fairy    270  115      45
# 94        74      Geodude Alolan Geodude  Rock Electric    300   40      80
# 93        74                     Geodude    Rock Ground    300   40      80
# 103       79                    Slowpoke  Water Psychic    315   90      65
# 104       79  Slowpoke Galarian Slowpoke        Psychic    315   90      65
#
#      Defense  Sp. Atk  Sp. Def  Speed    Type 1    Type 2
# 132       70       80       80    150  Electric      None
# 181       65       60       75    130      Rock    Flying
# 174       60      110       95    130  Electric      None
# 190       90      154       90    130   Psychic      None
# 33        50       75       60    120  Electric      None
# ..       ...      ...      ...    ...       ...       ...
# 52        20       45       25     20    Normal     Fairy
# 94       100       30       30     20      Rock  Electric
# 93       100       30       30     20      Rock    Ground
# 103       65       40       40     15     Water   Psychic
# 104       65       40       40     15   Psychic      None
#
# [179 rows x 12 columns]

# %% [markdown]
# ## Whick pokemons have a mega evolution?

# %%
df_pokedex.loc[df_pokedex["Name"].str.contains("Mega")]
# Out:
#      Pokedex                        Name              Type  Total   HP  \
# 3          3      Venusaur Mega Venusaur      Grass Poison    625   80
# 7          6  Charizard Mega Charizard X       Fire Dragon    634   78
# 8          6  Charizard Mega Charizard Y       Fire Flying    634   78
# 12         9    Blastoise Mega Blastoise             Water    630   79
# 19        15      Beedrill Mega Beedrill        Bug Poison    495   65
# 23        18        Pidgeot Mega Pidgeot     Normal Flying    579   83
# 84        65      Alakazam Mega Alakazam           Psychic    600   55
# 106       80        Slowbro Mega Slowbro     Water Psychic    590   95
# 125       94          Gengar Mega Gengar      Ghost Poison    600   60
# 150      115  Kangaskhan Mega Kangaskhan            Normal    590  105
# 164      127          Pinsir Mega Pinsir        Bug Flying    600   65
# 168      130      Gyarados Mega Gyarados        Water Dark    640   95
# 182      142  Aerodactyl Mega Aerodactyl       Rock Flying    615   80
# 191      150        Mewtwo Mega Mewtwo X  Psychic Fighting    780  106
# 192      150        Mewtwo Mega Mewtwo Y           Psychic    780  106
# 196      154                    Meganium             Grass    525   80
# 224      181      Ampharos Mega Ampharos   Electric Dragon    610   90
# 252      208        Steelix Mega Steelix      Steel Ground    610   75
# 257      212          Scizor Mega Scizor         Bug Steel    600   70
# 260      214    Heracross Mega Heracross      Bug Fighting    600   80
# 277      229      Houndoom Mega Houndoom         Dark Fire    600   75
# 297      248    Tyranitar Mega Tyranitar         Rock Dark    700  100
# 304      254      Sceptile Mega Sceptile      Grass Dragon    630   70
# 308      257      Blaziken Mega Blaziken     Fire Fighting    630   80
# 312      260      Swampert Mega Swampert      Water Ground    635  100
# 337      282    Gardevoir Mega Gardevoir     Psychic Fairy    618   68
# 358      302        Sableye Mega Sableye        Dark Ghost    480   50
# 360      303          Mawile Mega Mawile       Steel Fairy    480   50
# 364      306          Aggron Mega Aggron             Steel    630   70
# 367      308      Medicham Mega Medicham  Fighting Psychic    510   60
# 370      310    Manectric Mega Manectric          Electric    575   70
# 380      319      Sharpedo Mega Sharpedo        Water Dark    560   70
# 385      323      Camerupt Mega Camerupt       Fire Ground    560   70
# 397      334        Altaria Mega Altaria      Dragon Fairy    590   75
# 421      354        Banette Mega Banette             Ghost    555   64
# 427      359            Absol Mega Absol              Dark    565   65
# 431      362          Glalie Mega Glalie               Ice    580   80
# 443      373    Salamence Mega Salamence     Dragon Flying    700   95
# 447      376    Metagross Mega Metagross     Steel Psychic    700   80
# 452      380          Latias Mega Latias    Dragon Psychic    700   80
# 454      381          Latios Mega Latios    Dragon Psychic    700   80
# 460      384      Rayquaza Mega Rayquaza     Dragon Flying    780  105
# 510      428        Lopunny Mega Lopunny   Normal Fighting    580   65
# 528      445      Garchomp Mega Garchomp     Dragon Ground    700  108
# 532      448        Lucario Mega Lucario    Fighting Steel    625   70
# 545      460    Abomasnow Mega Abomasnow         Grass Ice    594   90
# 561      475        Gallade Mega Gallade  Psychic Fighting    618   68
# 625      531          Audino Mega Audino      Normal Fairy    545  103
# 839      719        Diancie Mega Diancie        Rock Fairy    700   50
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed    Type 1    Type 2
# 3       100      123      122      120     80     Grass    Poison
# 7       130      111      130       85    100      Fire    Dragon
# 8       104       78      159      115    100      Fire    Flying
# 12      103      120      135      115     78     Water      None
# 19      150       40       15       80    145       Bug    Poison
# 23       80       80      135       80    121    Normal    Flying
# 84       50       65      175      105    150   Psychic      None
# 106      75      180      130       80     30     Water   Psychic
# 125      65       80      170       95    130     Ghost    Poison
# 150     125      100       60      100    100    Normal      None
# 164     155      120       65       90    105       Bug    Flying
# 168     155      109       70      130     81     Water      Dark
# 182     135       85       70       95    150      Rock    Flying
# 191     190      100      154      100    130   Psychic  Fighting
# 192     150       70      194      120    140   Psychic      None
# 196      82      100       83      100     80     Grass      None
# 224      95      105      165      110     45  Electric    Dragon
# 252     125      230       55       95     30     Steel    Ground
# 257     150      140       65      100     75       Bug     Steel
# 260     185      115       40      105     75       Bug  Fighting
# 277      90       90      140       90    115      Dark      Fire
# 297     164      150       95      120     71      Rock      Dark
# 304     110       75      145       85    145     Grass    Dragon
# 308     160       80      130       80    100      Fire  Fighting
# 312     150      110       95      110     70     Water    Ground
# 337      85       65      165      135    100   Psychic     Fairy
# 358      85      125       85      115     20      Dark     Ghost
# 360     105      125       55       95     50     Steel     Fairy
# 364     140      230       60       80     50     Steel      None
# 367     100       85       80       85    100  Fighting   Psychic
# 370      75       80      135       80    135  Electric      None
# 380     140       70      110       65    105     Water      Dark
# 385     120      100      145      105     20      Fire    Ground
# 397     110      110      110      105     80    Dragon     Fairy
# 421     165       75       93       83     75     Ghost      None
# 427     150       60      115       60    115      Dark      None
# 431     120       80      120       80    100       Ice      None
# 443     145      130      120       90    120    Dragon    Flying
# 447     145      150      105      110    110     Steel   Psychic
# 452     100      120      140      150    110    Dragon   Psychic
# 454     130      100      160      120    110    Dragon   Psychic
# 460     180      100      180      100    115    Dragon    Flying
# 510     136       94       54       96    135    Normal  Fighting
# 528     170      115      120       95     92    Dragon    Ground
# 532     145       88      140       70    112  Fighting     Steel
# 545     132      105      132      105     30     Grass       Ice
# 561     165       95       65      115    110   Psychic  Fighting
# 625      60      126       80      126     50    Normal     Fairy
# 839     160      110      160      110    110      Rock     Fairy

# %% [markdown]
# ## Which pokemon change type when they mega evolve?

# %%
df_megas = df_pokedex.loc[df_pokedex["Name"].str.contains("Mega")][["Pokedex", "Name", "Type"]]
df_megas.head()
# Out:
#     Pokedex                        Name          Type
# 3         3      Venusaur Mega Venusaur  Grass Poison
# 7         6  Charizard Mega Charizard X   Fire Dragon
# 8         6  Charizard Mega Charizard Y   Fire Flying
# 12        9    Blastoise Mega Blastoise         Water
# 19       15      Beedrill Mega Beedrill    Bug Poison

# %%
df_megas = df_megas.rename(columns = {"Name": "Mega Name", "Type": "Mega Type"})
df_megas.head()
# Out:
#     Pokedex                   Mega Name     Mega Type
# 3         3      Venusaur Mega Venusaur  Grass Poison
# 7         6  Charizard Mega Charizard X   Fire Dragon
# 8         6  Charizard Mega Charizard Y   Fire Flying
# 12        9    Blastoise Mega Blastoise         Water
# 19       15      Beedrill Mega Beedrill    Bug Poison

# %%
#inner join
df_pokedex_megas = pandas.merge(df_pokedex, df_megas, on = "Pokedex")
df_pokedex_megas
# Out:
#      Pokedex                        Name              Type  Total   HP  \
# 0          3                    Venusaur      Grass Poison    525   80
# 1          3      Venusaur Mega Venusaur      Grass Poison    625   80
# 2          6                   Charizard       Fire Flying    534   78
# 3          6                   Charizard       Fire Flying    534   78
# 4          6  Charizard Mega Charizard X       Fire Dragon    634   78
# ..       ...                         ...               ...    ...  ...
# 97       475        Gallade Mega Gallade  Psychic Fighting    618   68
# 98       531                      Audino            Normal    445  103
# 99       531          Audino Mega Audino      Normal Fairy    545  103
# 100      719                     Diancie        Rock Fairy    600   50
# 101      719        Diancie Mega Diancie        Rock Fairy    700   50
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed   Type 1    Type 2  \
# 0        82       83      100      100     80    Grass    Poison
# 1       100      123      122      120     80    Grass    Poison
# 2        84       78      109       85    100     Fire    Flying
# 3        84       78      109       85    100     Fire    Flying
# 4       130      111      130       85    100     Fire    Dragon
# ..      ...      ...      ...      ...    ...      ...       ...
# 97      165       95       65      115    110  Psychic  Fighting
# 98       60       86       60       86     50   Normal      None
# 99       60      126       80      126     50   Normal     Fairy
# 100     100      150      100      150     50     Rock     Fairy
# 101     160      110      160      110    110     Rock     Fairy
#
#                       Mega Name         Mega Type
# 0        Venusaur Mega Venusaur      Grass Poison
# 1        Venusaur Mega Venusaur      Grass Poison
# 2    Charizard Mega Charizard X       Fire Dragon
# 3    Charizard Mega Charizard Y       Fire Flying
# 4    Charizard Mega Charizard X       Fire Dragon
# ..                          ...               ...
# 97         Gallade Mega Gallade  Psychic Fighting
# 98           Audino Mega Audino      Normal Fairy
# 99           Audino Mega Audino      Normal Fairy
# 100        Diancie Mega Diancie        Rock Fairy
# 101        Diancie Mega Diancie        Rock Fairy
#
# [102 rows x 14 columns]

# %%
df_pokedex_megas.loc[df_pokedex_megas["Type"] != df_pokedex_megas["Mega Type"]]
# Out:
#     Pokedex                        Name              Type  Total   HP  Attack  \
# 2         6                   Charizard       Fire Flying    534   78      84
# 5         6  Charizard Mega Charizard X       Fire Dragon    634   78     130
# 6         6  Charizard Mega Charizard Y       Fire Flying    634   78     104
# 18       80    Slowbro Galarian Slowbro    Poison Psychic    490   95     100
# 23      127                      Pinsir               Bug    500   65     125
# 25      130                    Gyarados      Water Flying    540   95     125
# 29      150                      Mewtwo           Psychic    680  106     110
# 32      150        Mewtwo Mega Mewtwo X  Psychic Fighting    780  106     190
# 33      150        Mewtwo Mega Mewtwo Y           Psychic    780  106     150
# 36      181                    Ampharos          Electric    510   90      75
# 48      254                    Sceptile             Grass    530   70      85
# 60      306                      Aggron        Steel Rock    530   70     110
# 70      334                     Altaria     Dragon Flying    490   75      70
# 88      428                     Lopunny            Normal    480   65      76
# 98      531                      Audino            Normal    445  103      60
#
#     Defense  Sp. Atk  Sp. Def  Speed    Type 1    Type 2  \
# 2        78      109       85    100      Fire    Flying
# 5       111      130       85    100      Fire    Dragon
# 6        78      159      115    100      Fire    Flying
# 18       95      100       70     30    Poison   Psychic
# 23      100       55       70     85       Bug      None
# 25       79       60      100     81     Water    Flying
# 29       90      154       90    130   Psychic      None
# 32      100      154      100    130   Psychic  Fighting
# 33       70      194      120    140   Psychic      None
# 36       85      115       90     55  Electric      None
# 48       65      105       85    120     Grass      None
# 60      180       60       60     50     Steel      Rock
# 70       90       70      105     80    Dragon    Flying
# 88       84       54       96    105    Normal      None
# 98       86       60       86     50    Normal      None
#
#                      Mega Name         Mega Type
# 2   Charizard Mega Charizard X       Fire Dragon
# 5   Charizard Mega Charizard Y       Fire Flying
# 6   Charizard Mega Charizard X       Fire Dragon
# 18        Slowbro Mega Slowbro     Water Psychic
# 23          Pinsir Mega Pinsir        Bug Flying
# 25      Gyarados Mega Gyarados        Water Dark
# 29        Mewtwo Mega Mewtwo X  Psychic Fighting
# 32        Mewtwo Mega Mewtwo Y           Psychic
# 33        Mewtwo Mega Mewtwo X  Psychic Fighting
# 36      Ampharos Mega Ampharos   Electric Dragon
# 48      Sceptile Mega Sceptile      Grass Dragon
# 60          Aggron Mega Aggron             Steel
# 70        Altaria Mega Altaria      Dragon Fairy
# 88        Lopunny Mega Lopunny   Normal Fighting
# 98          Audino Mega Audino      Normal Fairy

# %% [markdown]
# # What's next?
#
# * Groupping and aggregating functions
# * Merging dataframes (joins, appends)
# * Apply vectorized functions
# * Working with Big Data
# * Pandas pro tips and tricks

# %% [markdown]
# # Contact

# %% [markdown]
# Manuel Montoya
# * Correo: manuel.montoya@pucp.edu.pe
# * Linkedin: https://www.linkedin.com/in/manuel-montoya-gamio/
#
# <img src="https://miro.medium.com/max/3006/1*KdxlBR9P3mDp9JZ_URMdYQ.jpeg">
