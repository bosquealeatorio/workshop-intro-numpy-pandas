# %% [markdown]
# # sql queries on pandas

# %% [markdown]
# **Aditional resources:**
#
# * Comparison with SQL on the pandas documentation: https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html

# %% [markdown]
# <img src = "https://i.imgflip.com/47k7yb.jpg">

# %% [markdown]
# # libraries

# %%
import pandas

import seaborn
import matplotlib.pyplot as plt

import time
import sys
import os

# %% [markdown]
# ## data tables

# %%
os.listdir("data/olympics")
# Out:
# ['.DS_Store',
#  'athletes.csv',
#  'medalist.csv',
#  'games.csv',
#  'athlete_events.csv',
#  'events.csv']

# %%
[file for file in os.listdir("data/olympics") if ".csv" in file]
# Out:
# ['athletes.csv',
#  'medalist.csv',
#  'games.csv',
#  'athlete_events.csv',
#  'events.csv']

# %%
games = pandas.read_csv("data/olympics/games.csv")
events = pandas.read_csv("data/olympics/events.csv")
athletes = pandas.read_csv("data/olympics/athletes.csv")
medalists = pandas.read_csv("data/olympics/medalist.csv")

# %%
games.head()
# Out:
#    id_games        Games  Year  Season       City
# 0         0  1896 Summer  1896  Summer     Athina
# 1         1  1900 Summer  1900  Summer      Paris
# 2         2  1904 Summer  1904  Summer  St. Louis
# 3         3  1906 Summer  1906  Summer     Athina
# 4         4  1908 Summer  1908  Summer     London

# %%
events.head()
# Out:
#    id_event        Games      Sport                                Event  \
# 0         0  1896 Summer  Athletics            Athletics Men's High Jump
# 1         1  1896 Summer  Athletics           Athletics Men's 100 metres
# 2         2  1896 Summer     Tennis                 Tennis Men's Singles
# 3         3  1896 Summer    Cycling  Cycling Men's 333 metres Time Trial
# 4         4  1896 Summer     Tennis                 Tennis Men's Doubles
#
#    id_games
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %%
medalists.head()
# Out:
#    id_athlete  id_event   Medal
# 0       35698         4  Bronze
# 1       12929         4    Gold
# 2      101352         4  Bronze
# 3      121713         4    Gold
# 4       18785         4  Silver

# %% [markdown]
# ## SELECT columns

# %% [markdown]
# `select columns from games`

# %%
games.head()
# Out:
#    id_games        Games  Year  Season       City
# 0         0  1896 Summer  1896  Summer     Athina
# 1         1  1900 Summer  1900  Summer      Paris
# 2         2  1904 Summer  1904  Summer  St. Louis
# 3         3  1906 Summer  1906  Summer     Athina
# 4         4  1908 Summer  1908  Summer     London

# %%
games.head()[["id_games", "Games"]]
# Out:
#    id_games        Games
# 0         0  1896 Summer
# 1         1  1900 Summer
# 2         2  1904 Summer
# 3         3  1906 Summer
# 4         4  1908 Summer

# %%
games.head().get(["id_games", "Games"])
# Out:
#    id_games        Games
# 0         0  1896 Summer
# 1         1  1900 Summer
# 2         2  1904 Summer
# 3         3  1906 Summer
# 4         4  1908 Summer

# %% [markdown]
# *select columns by pattern*

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %%
columns_selected = [column for column in athletes.columns if "id" in column]
athletes.get(columns_selected)
# Out:
#         id_athlete  id_event  id_games
# 0                1      3723        37
# 1                2      5676        48
# 2                3       671         6
# 3                4       127         1
# 4                5      3593        36
# ...            ...       ...       ...
# 187447      135568      5932        50
# 187448      135569      2822        30
# 187449      135570      5834        49
# 187450      135571      4308        41
# 187451      135571      4655        43
#
# [187452 rows x 3 columns]

# %% [markdown]
# *select column by type*

# %%
medalists.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %%
medalists.select_dtypes("float")
# Out:
#          Age  Height  Weight
# 0       24.0   180.0    80.0
# 1       23.0   170.0    60.0
# 2       24.0     NaN     NaN
# 3       34.0     NaN     NaN
# 4       21.0   185.0    82.0
# ...      ...     ...     ...
# 187447  33.0   171.0    69.0
# 187448  29.0   179.0    89.0
# 187449  27.0   176.0    59.0
# 187450  30.0   185.0    96.0
# 187451  34.0   185.0    96.0
#
# [187452 rows x 3 columns]

# %% [markdown]
# ## JOINS
#
# `
# select a.columns, b.columns
# from  a left join b
# on a.key = b.key`

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %%
len(athletes)
# Out:
# 187452

# %%
events.head()
# Out:
#    id_event        Games      Sport                                Event  \
# 0         0  1896 Summer  Athletics            Athletics Men's High Jump
# 1         1  1896 Summer  Athletics           Athletics Men's 100 metres
# 2         2  1896 Summer     Tennis                 Tennis Men's Singles
# 3         3  1896 Summer    Cycling  Cycling Men's 333 metres Time Trial
# 4         4  1896 Summer     Tennis                 Tennis Men's Doubles
#
#    id_games
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# *join on one key vs join on two keys*

# %%
athletes_by_event = pandas.merge(athletes, events, on = ["id_event", "id_games"], how = "left")

# %%
len(athletes_by_event)
# Out:
# 187452

# %%
athletes_by_event.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games        Games          Sport  \
# 0      3723        37  1992 Summer     Basketball
# 1      5676        48  2012 Summer           Judo
# 2       671         6  1920 Summer       Football
# 3       127         1  1900 Summer     Tug-Of-War
# 4      3593        36  1988 Winter  Speed Skating
#
#                               Event
# 0       Basketball Men's Basketball
# 1      Judo Men's Extra-Lightweight
# 2           Football Men's Football
# 3       Tug-Of-War Men's Tug-Of-War
# 4  Speed Skating Women's 500 metres

# %%
athletes_event_games = pandas.merge(athletes_by_event, games[["id_games", "Season", "City"]], how = "left")

# %%
len(athletes_event_games)
# Out:
# 187452

# %%
athletes_event_games.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games        Games          Sport  \
# 0      3723        37  1992 Summer     Basketball
# 1      5676        48  2012 Summer           Judo
# 2       671         6  1920 Summer       Football
# 3       127         1  1900 Summer     Tug-Of-War
# 4      3593        36  1988 Winter  Speed Skating
#
#                               Event  Season       City
# 0       Basketball Men's Basketball  Summer  Barcelona
# 1      Judo Men's Extra-Lightweight  Summer     London
# 2           Football Men's Football  Summer  Antwerpen
# 3       Tug-Of-War Men's Tug-Of-War  Summer      Paris
# 4  Speed Skating Women's 500 metres  Winter    Calgary

# %%
medalists.head()
# Out:
#    athlete_id  id_event   Medal
# 0       35698         4  Bronze
# 1       12929         4    Gold
# 2      101352         4  Bronze
# 3      121713         4    Gold
# 4       18785         4  Silver

# %%
full_dataset = pandas.merge(athletes_event_games, medalists, 
                            left_on = ["id_athlete", "id_event"], 
                            right_on = ["athlete_id", "id_event"], 
                            how = "left")

# %%
len(full_dataset)
# Out:
# 187452

# %%
full_dataset.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games        Games          Sport  \
# 0      3723        37  1992 Summer     Basketball
# 1      5676        48  2012 Summer           Judo
# 2       671         6  1920 Summer       Football
# 3       127         1  1900 Summer     Tug-Of-War
# 4      3593        36  1988 Winter  Speed Skating
#
#                               Event  Season       City  athlete_id Medal
# 0       Basketball Men's Basketball  Summer  Barcelona         NaN   NaN
# 1      Judo Men's Extra-Lightweight  Summer     London         NaN   NaN
# 2           Football Men's Football  Summer  Antwerpen         NaN   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Summer      Paris         4.0  Gold
# 4  Speed Skating Women's 500 metres  Winter    Calgary         NaN   NaN

# %%
full_dataset.loc[~full_dataset["Medal"].isnull()].head()
# Out:
#     id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 20          15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  FIN
# 22          16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  FIN
# 23          17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  FIN
# 28          20        Kjetil Andr Aamodt   M  22.0   176.0    85.0  NOR
#
#     id_event  id_games        Games          Sport  \
# 3        127         1  1900 Summer     Tug-Of-War
# 20       672         6  1920 Summer       Swimming
# 22      5800        49  2014 Winter     Ice Hockey
# 23      1347        15  1948 Summer     Gymnastics
# 28      3993        39  1994 Winter  Alpine Skiing
#
#                                      Event  Season         City  athlete_id  \
# 3              Tug-Of-War Men's Tug-Of-War  Summer        Paris         4.0
# 20  Swimming Men's 200 metres Breaststroke  Summer    Antwerpen        15.0
# 22             Ice Hockey Men's Ice Hockey  Winter        Sochi        16.0
# 23  Gymnastics Men's Individual All-Around  Summer       London        17.0
# 28            Alpine Skiing Men's Downhill  Winter  Lillehammer        20.0
#
#      Medal
# 3     Gold
# 20  Bronze
# 22  Bronze
# 23  Bronze
# 28  Silver

# %%
full_dataset = full_dataset[[column for column in full_dataset.columns if "id" not in column]]
full_dataset.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Season       City Medal
# 0     Basketball       Basketball Men's Basketball  Summer  Barcelona   NaN
# 1           Judo      Judo Men's Extra-Lightweight  Summer     London   NaN
# 2       Football           Football Men's Football  Summer  Antwerpen   NaN
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Summer      Paris  Gold
# 4  Speed Skating  Speed Skating Women's 500 metres  Winter    Calgary   NaN

# %% [markdown]
# ## NVL
# `select nvl(column, value_to_fill) from table`

# %%
full_dataset["Medal"] = full_dataset["Medal"].fillna("No Medal")

# %%
full_dataset.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Season       City  \
# 0     Basketball       Basketball Men's Basketball  Summer  Barcelona
# 1           Judo      Judo Men's Extra-Lightweight  Summer     London
# 2       Football           Football Men's Football  Summer  Antwerpen
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Summer      Paris
# 4  Speed Skating  Speed Skating Women's 500 metres  Winter    Calgary
#
#       Medal
# 0  No Medal
# 1  No Medal
# 2  No Medal
# 3      Gold
# 4  No Medal

# %% [markdown]
# ## SELECT WHERE
#
# `select columns where condition`

# %%
full_dataset.loc[(athletes["Sex"] == "F") & (athletes["NOC"] == "PER")]
# Out:
#                                              Name Sex   Age  Height  Weight  \
# 2047                           Fiorella Ata Junek   F  23.0   170.0    65.0
# 6840                  Wilma Yanet Arizapana Yucra   F  29.0   164.0    54.0
# 7379                           Olga Asato Hichiva   F  19.0   166.0    65.0
# 8418                               Mara Pia Ayora   F  18.0   178.0    68.0
# 9728    E. Gladys Baldwin Lopez (-de Seminario-)    F  31.0   167.0    67.0
# ...                                           ...  ..   ...     ...     ...
# 173780                      Norma Velarde Alvarez   F  21.0   169.0    74.0
# 173796           Claudia Silvana Velsquez Ponzoni   F  16.0     NaN     NaN
# 174952                    Mara Luisa Vilca Alzola   F  24.0   164.0    58.0
# 185060                 Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0
# 185061                 Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0
#
#         NOC        Games       Sport  \
# 2047    PER  2000 Summer  Volleyball
# 6840    PER  2012 Summer   Athletics
# 7379    PER  1968 Summer  Volleyball
# 8418    PER  1980 Summer    Swimming
# 9728    PER  1968 Summer    Shooting
# ...     ...          ...         ...
# 173780  PER  1968 Summer  Volleyball
# 173796  PER  1992 Summer    Swimming
# 174952  PER  1972 Summer   Athletics
# 185060  PER  1996 Summer  Volleyball
# 185061  PER  2000 Summer  Volleyball
#
#                                                     Event  Season  \
# 2047                        Volleyball Women's Volleyball  Summer
# 6840                           Athletics Women's Marathon  Summer
# 7379                        Volleyball Women's Volleyball  Summer
# 8418                Swimming Women's 400 metres Freestyle  Summer
# 9728    Shooting Mixed Small-Bore Rifle, Prone, 50 metres  Summer
# ...                                                   ...     ...
# 173780                      Volleyball Women's Volleyball  Summer
# 173796           Swimming Women's 100 metres Breaststroke  Summer
# 174952                       Athletics Women's 100 metres  Summer
# 185060                      Volleyball Women's Volleyball  Summer
# 185061                      Volleyball Women's Volleyball  Summer
#
#                City     Medal
# 2047         Sydney  No Medal
# 6840         London  No Medal
# 7379    Mexico City  No Medal
# 8418         Moskva  No Medal
# 9728    Mexico City  No Medal
# ...             ...       ...
# 173780  Mexico City  No Medal
# 173796    Barcelona  No Medal
# 174952       Munich  No Medal
# 185060      Atlanta  No Medal
# 185061       Sydney  No Medal
#
# [136 rows x 12 columns]

# %% [markdown]
# `select column where column like '%pattern %'`

# %% [markdown]
# *Winklevoss*

# %%
full_dataset.loc[athletes["Name"].str.contains("Winklevoss")]
# Out:
#                              Name Sex   Age  Height  Weight  NOC        Games  \
# 181082  Cameron Howard Winklevoss   M  26.0   196.0    96.0  USA  2008 Summer
# 181083    Tyler Howard Winklevoss   M  26.0   196.0    95.0  USA  2008 Summer
#
#          Sport                       Event  Season     City     Medal
# 181082  Rowing  Rowing Men's Coxless Pairs  Summer  Beijing  No Medal
# 181083  Rowing  Rowing Men's Coxless Pairs  Summer  Beijing  No Medal

# %%
full_dataset.loc[athletes["Name"].str.lower().str.contains("montoya")]
# Out:
#                                      Name Sex   Age  Height  Weight  NOC  \
# 65447           Sergio Luis Henao Montoya   M  24.0   170.0    61.0  COL
# 65448           Sergio Luis Henao Montoya   M  28.0   170.0    61.0  COL
# 66223             Armando Herrera Montoya   M  24.0   170.0    69.0  MEX
# 66224             Armando Herrera Montoya   M  28.0   170.0    69.0  MEX
# 92573          Jos Luis Laverdeza Montoya   M  19.0   167.0    67.0  CUB
# 107602                Luis Medina Montoya   M  24.0   176.0    63.0  CUB
# 112455             Alejandro Montoya Vera   M  20.0   169.0    74.0  CUB
# 112456         Ana Mara Montoya Prophater   F  20.0   169.0    62.0  COL
# 112457             Daniela Montoya Quiroz   F  21.0   158.0    55.0  COL
# 112458         Elmer Roberto Montoya Meza   M  22.0   175.0    72.0  HON
# 112459             Hugo Francisco Montoya   M  27.0   176.0    75.0  GUA
# 112460            Isidro Montoya Valencia   M  21.0   176.0    68.0  COL
# 112461                   Juan Jos Montoya   M  19.0     NaN     NaN  GUA
# 112462  Mara de Lourdes Montoya Castorena   F  26.0   164.0    59.0  MEX
# 112463  Mara de Lourdes Montoya Castorena   F  34.0   164.0    59.0  MEX
# 112464      Mario Enrique Montoya Segnini   M  18.0   195.0    96.0  CRC
# 112465      Mario Enrique Montoya Segnini   M  22.0   195.0    96.0  CRC
# 112466             Martn Montoya Torralbo   M  21.0   174.0    74.0  ESP
# 112467       Paolo Cesar Montoya Cantillo   M  27.0   186.0    71.0  CRC
# 125005          Hctor Ivn Palacio Montoya   M  23.0   167.0    63.0  COL
# 168426             Jos Luis Trejo Montoya   M  21.0   180.0    71.0  MEX
#
#               Games       Sport                                      Event  \
# 65447   2012 Summer     Cycling        Cycling Men's Road Race, Individual
# 65448   2016 Summer     Cycling        Cycling Men's Road Race, Individual
# 66223   1960 Summer  Basketball                Basketball Men's Basketball
# 66224   1964 Summer  Basketball                Basketball Men's Basketball
# 92573   1980 Summer     Fencing            Fencing Men's Sabre, Individual
# 107602  1976 Summer   Athletics                 Athletics Men's 800 metres
# 112455  1972 Summer      Boxing                  Boxing Men's Middleweight
# 112456  2012 Summer    Football                  Football Women's Football
# 112457  2012 Summer    Football                  Football Women's Football
# 112458  2000 Summer    Football                    Football Men's Football
# 112459  1968 Summer    Football                    Football Men's Football
# 112460  2012 Summer   Athletics                 Athletics Men's 100 metres
# 112461  1952 Summer     Cycling   Cycling Men's Team Pursuit, 4,000 metres
# 112462  1992 Summer      Rowing               Rowing Women's Double Sculls
# 112463  2000 Summer      Rowing   Rowing Women's Lightweight Double Sculls
# 112464  2008 Summer    Swimming        Swimming Men's 200 metres Freestyle
# 112465  2012 Summer    Swimming        Swimming Men's 200 metres Freestyle
# 112466  2012 Summer    Football                    Football Men's Football
# 112467  2012 Summer     Cycling  Cycling Men's Mountainbike, Cross-Country
# 125005  1992 Summer     Cycling        Cycling Men's Road Race, Individual
# 168426  1972 Summer    Football                    Football Men's Football
#
#         Season            City     Medal
# 65447   Summer          London  No Medal
# 65448   Summer  Rio de Janeiro  No Medal
# 66223   Summer            Roma  No Medal
# 66224   Summer           Tokyo  No Medal
# 92573   Summer          Moskva  No Medal
# 107602  Summer        Montreal  No Medal
# 112455  Summer          Munich  No Medal
# 112456  Summer          London  No Medal
# 112457  Summer          London  No Medal
# 112458  Summer          Sydney  No Medal
# 112459  Summer     Mexico City  No Medal
# 112460  Summer          London  No Medal
# 112461  Summer        Helsinki  No Medal
# 112462  Summer       Barcelona  No Medal
# 112463  Summer          Sydney  No Medal
# 112464  Summer         Beijing  No Medal
# 112465  Summer          London  No Medal
# 112466  Summer          London  No Medal
# 112467  Summer          London  No Medal
# 125005  Summer       Barcelona  No Medal
# 168426  Summer          Munich  No Medal

# %%
full_dataset.loc[(athletes_by_event["NOC"] == "PER") & (athletes_by_event["Sex"] == "F")]
# Out:
#                                              Name Sex   Age  Height  Weight  \
# 2047                           Fiorella Ata Junek   F  23.0   170.0    65.0
# 6840                  Wilma Yanet Arizapana Yucra   F  29.0   164.0    54.0
# 7379                           Olga Asato Hichiva   F  19.0   166.0    65.0
# 8418                               Mara Pia Ayora   F  18.0   178.0    68.0
# 9728    E. Gladys Baldwin Lopez (-de Seminario-)    F  31.0   167.0    67.0
# ...                                           ...  ..   ...     ...     ...
# 173780                      Norma Velarde Alvarez   F  21.0   169.0    74.0
# 173796           Claudia Silvana Velsquez Ponzoni   F  16.0     NaN     NaN
# 174952                    Mara Luisa Vilca Alzola   F  24.0   164.0    58.0
# 185060                 Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0
# 185061                 Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0
#
#         NOC        Games       Sport  \
# 2047    PER  2000 Summer  Volleyball
# 6840    PER  2012 Summer   Athletics
# 7379    PER  1968 Summer  Volleyball
# 8418    PER  1980 Summer    Swimming
# 9728    PER  1968 Summer    Shooting
# ...     ...          ...         ...
# 173780  PER  1968 Summer  Volleyball
# 173796  PER  1992 Summer    Swimming
# 174952  PER  1972 Summer   Athletics
# 185060  PER  1996 Summer  Volleyball
# 185061  PER  2000 Summer  Volleyball
#
#                                                     Event  Season  \
# 2047                        Volleyball Women's Volleyball  Summer
# 6840                           Athletics Women's Marathon  Summer
# 7379                        Volleyball Women's Volleyball  Summer
# 8418                Swimming Women's 400 metres Freestyle  Summer
# 9728    Shooting Mixed Small-Bore Rifle, Prone, 50 metres  Summer
# ...                                                   ...     ...
# 173780                      Volleyball Women's Volleyball  Summer
# 173796           Swimming Women's 100 metres Breaststroke  Summer
# 174952                       Athletics Women's 100 metres  Summer
# 185060                      Volleyball Women's Volleyball  Summer
# 185061                      Volleyball Women's Volleyball  Summer
#
#                City     Medal
# 2047         Sydney  No Medal
# 6840         London  No Medal
# 7379    Mexico City  No Medal
# 8418         Moskva  No Medal
# 9728    Mexico City  No Medal
# ...             ...       ...
# 173780  Mexico City  No Medal
# 173796    Barcelona  No Medal
# 174952       Munich  No Medal
# 185060      Atlanta  No Medal
# 185061       Sydney  No Medal
#
# [136 rows x 12 columns]

# %%
athletes_PER = full_dataset.loc[(full_dataset["NOC"] == "PER") & (full_dataset["Sex"] == "F")]
athletes_PER.get(["Name", "Games"]).groupby("Name", as_index = False).count().sort_values(by = "Games", ascending = False)
# Out:
#                               Name  Games
# 71        Natalia Mara Mlaga Dibos      4
# 11  Cecilia Roxana Tait Villacorta      3
# 82         Santa Ins Melchor Huiza      3
# 50          Mara Cecilia del Risco      3
# 79        Rosa Gisella Garca Rivas      3
# ..                             ...    ...
# 39              Kimberly Garca Len      1
# 38         Katherine "Kathy" Horny      1
# 37                   Karin Brandes      1
# 36                   Karen Horning      1
# 47                   Magaly Montes      1
#
# [95 rows x 2 columns]

# %%
full_dataset.loc[athletes["Name"] == "Natalia Mara Mlaga Dibos"]
# Out:
#                             Name Sex   Age  Height  Weight  NOC        Games  \
# 101868  Natalia Mara Mlaga Dibos   F  16.0   170.0    59.0  PER  1980 Summer
# 101869  Natalia Mara Mlaga Dibos   F  20.0   170.0    59.0  PER  1984 Summer
# 101870  Natalia Mara Mlaga Dibos   F  24.0   170.0    59.0  PER  1988 Summer
# 101871  Natalia Mara Mlaga Dibos   F  36.0   170.0    59.0  PER  2000 Summer
#
#              Sport                          Event  Season         City  \
# 101868  Volleyball  Volleyball Women's Volleyball  Summer       Moskva
# 101869  Volleyball  Volleyball Women's Volleyball  Summer  Los Angeles
# 101870  Volleyball  Volleyball Women's Volleyball  Summer        Seoul
# 101871  Volleyball  Volleyball Women's Volleyball  Summer       Sydney
#
#            Medal
# 101868  No Medal
# 101869  No Medal
# 101870    Silver
# 101871  No Medal

# %%
full_dataset.loc[(full_dataset["NOC"] == "PER") & 
                 (full_dataset["Sport"] == "Volleyball") &
                 (full_dataset["Games"] == "1988 Summer")]
# Out:
#                                                    Name Sex   Age  Height  \
# 26619                      Luisa Haydee Cervera Cevedon   F  24.0   173.0
# 35983                            Alejandra de la Guerra   F  20.0   173.0
# 46458                             Denisse Fajardo Garca   F  24.0   171.0
# 52523                                   Miriam Gallardo   F  20.0   168.0
# 53348                          Rosa Gisella Garca Rivas   F  24.0   175.0
# 65911                              Sonia Isabel Heredia   F  24.0   175.0
# 68832                           Katherine "Kathy" Horny   F  18.0   186.0
# 101870                         Natalia Mara Mlaga Dibos   F  24.0   170.0
# 128653  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0   194.0
# 162855                   Cecilia Roxana Tait Villacorta   F  26.0   182.0
# 167621                                   Gina Torrealva   F  26.0   175.0
# 170777                  Cenaida Cebastiana Uribe Medina   F  22.0   174.0
#
#         Weight  NOC        Games       Sport                          Event  \
# 26619     70.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 35983     59.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 46458     62.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 52523     57.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 53348     69.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 65911     69.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 68832     76.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 101870    59.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 128653    72.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 162855    70.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 167621    59.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 170777    65.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
#
#         Season   City   Medal
# 26619   Summer  Seoul  Silver
# 35983   Summer  Seoul  Silver
# 46458   Summer  Seoul  Silver
# 52523   Summer  Seoul  Silver
# 53348   Summer  Seoul  Silver
# 65911   Summer  Seoul  Silver
# 68832   Summer  Seoul  Silver
# 101870  Summer  Seoul  Silver
# 128653  Summer  Seoul  Silver
# 162855  Summer  Seoul  Silver
# 167621  Summer  Seoul  Silver
# 170777  Summer  Seoul  Silver

# %% [markdown]
# ## SELECT DISTINCT

# %% [markdown]
# `select distinct column from table`

# %%
full_dataset.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Season       City  \
# 0     Basketball       Basketball Men's Basketball  Summer  Barcelona
# 1           Judo      Judo Men's Extra-Lightweight  Summer     London
# 2       Football           Football Men's Football  Summer  Antwerpen
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Summer      Paris
# 4  Speed Skating  Speed Skating Women's 500 metres  Winter    Calgary
#
#       Medal
# 0  No Medal
# 1  No Medal
# 2  No Medal
# 3      Gold
# 4  No Medal

# %%
full_dataset["City"].unique()
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %%
full_dataset.get("City").drop_duplicates()
# Out:
# 0                   Barcelona
# 1                      London
# 2                   Antwerpen
# 3                       Paris
# 4                     Calgary
# 5                 Albertville
# 6                 Lillehammer
# 11                Los Angeles
# 12             Salt Lake City
# 13                   Helsinki
# 14                Lake Placid
# 15                     Sydney
# 16                    Atlanta
# 19                  Stockholm
# 22                      Sochi
# 29                     Nagano
# 31                     Torino
# 32                    Beijing
# 33             Rio de Janeiro
# 35                     Athina
# 36               Squaw Valley
# 37                  Innsbruck
# 39                   Sarajevo
# 41                Mexico City
# 42                     Munich
# 43                      Seoul
# 46                     Berlin
# 57                       Oslo
# 58          Cortina d'Ampezzo
# 69                  Melbourne
# 70                       Roma
# 73                  Amsterdam
# 80                   Montreal
# 119                    Moskva
# 123                     Tokyo
# 170                 Vancouver
# 191                  Grenoble
# 482                   Sapporo
# 520                  Chamonix
# 542                 St. Louis
# 706              Sankt Moritz
# 993    Garmisch-Partenkirchen
# Name: City, dtype: object

# %%
full_dataset["City"].nunique()
# Out:
# 42

# %% [markdown]
# ## GROUP BY COUNT

# %% [markdown]
# `select column, count()
# from table
# group by column`

# %%
full_dataset.get(["City", "Games"])\
            .drop_duplicates()\
            .groupby("City")\
            .count()
# Out:
#                         Games
# City
# Albertville                 1
# Amsterdam                   1
# Antwerpen                   1
# Athina                      3
# Atlanta                     1
# Barcelona                   1
# Beijing                     1
# Berlin                      1
# Calgary                     1
# Chamonix                    1
# Cortina d'Ampezzo           1
# Garmisch-Partenkirchen      1
# Grenoble                    1
# Helsinki                    1
# Innsbruck                   2
# Lake Placid                 2
# Lillehammer                 1
# London                      3
# Los Angeles                 2
# Melbourne                   1
# Mexico City                 1
# Montreal                    1
# Moskva                      1
# Munich                      1
# Nagano                      1
# Oslo                        1
# Paris                       2
# Rio de Janeiro              1
# Roma                        1
# Salt Lake City              1
# Sankt Moritz                2
# Sapporo                     1
# Sarajevo                    1
# Seoul                       1
# Sochi                       1
# Squaw Valley                1
# St. Louis                   1
# Stockholm                   1
# Sydney                      1
# Tokyo                       1
# Torino                      1
# Vancouver                   1

# %%
df_count = full_dataset.get(["City", "Games"])\
                        .drop_duplicates()\
                        .groupby("City")\
                        .count()

df_count.head()
# Out:
#              Games
# City
# Albertville      1
# Amsterdam        1
# Antwerpen        1
# Athina           3
# Atlanta          1

# %%
df_count.sort_values(by = "Games", ascending = False).head()
# Out:
#              Games
# City
# Athina           3
# London           3
# Paris            2
# Los Angeles      2
# Lake Placid      2

# %%
games.loc[games["City"] == "London"]
# Out:
#     id_games        Games  Year  Season    City
# 4          4  1908 Summer  1908  Summer  London
# 15        15  1948 Summer  1948  Summer  London
# 48        48  2012 Summer  2012  Summer  London

# %%
games.loc[games["City"] == "Paris"]
# Out:
#    id_games        Games  Year  Season   City
# 1         1  1900 Summer  1900  Summer  Paris
# 7         7  1924 Summer  1924  Summer  Paris

# %% [markdown]
# ## Union

# %%
os.listdir("data/olympics/")
# Out:
# ['split2.csv',
#  'split1.csv',
#  '.DS_Store',
#  'athletes.csv',
#  'medalist.csv',
#  'games.csv',
#  'athlete_events.csv',
#  'events.csv']

# %%
df1 = pandas.read_csv("data/olympics/split1.csv")
df2 = pandas.read_csv("data/olympics/split2.csv")

# %% [markdown]
# # Contact

# %% [markdown]
# Manuel Montoya
# * Mail: manuel.montoya@pucp.edu.pe
# * Linkedin: https://www.linkedin.com/in/manuel-montoya-gamio/

# %% [markdown]
# Numpy pain: https://www.reddit.com/r/ProgrammerHumor/comments/aouyj1/when_you_program_python_for_a_year_and_realize/
