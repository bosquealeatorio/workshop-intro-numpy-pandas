# %% [markdown]
# # sql queries on pandas

# %% [markdown]
# **Aditional resources:**
#
# * Comparison with SQL on the pandas documentation: https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html
#
# * Pandas merge documentation: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.merge.html

# %% [markdown]
# <img src = "https://i.imgflip.com/47k7yb.jpg">

# %% [markdown]
# # libraries

# %%
import pandas

import seaborn
import matplotlib.pyplot as plt

import time
import sys
import os
# Out:
# /Users/manuel/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## list files on a directory

# %% [markdown]
# *list files in a directory using linux commands*

# %%
# !ls data/olympics/
# Out:
# athlete_events.csv events.csv         medalist.csv       split2.csv
# athletes.csv       games.csv          split1.csv

# %% [markdown]
# *it's better to use commands agnostic to platform with os package*

# %%
os.listdir("data/olympics/")
# Out:
# ['split2.csv',
#  'split1.csv',
#  '.DS_Store',
#  'athletes.csv',
#  'medalist.csv',
#  'games.csv',
#  'athlete_events.csv',
#  'events.csv']

# %% [markdown]
# *getting files with one particular extension*

# %%
[file for file in os.listdir("data/olympics/") if file.endswith('.csv')]
# Out:
# ['split2.csv',
#  'split1.csv',
#  'athletes.csv',
#  'medalist.csv',
#  'games.csv',
#  'athlete_events.csv',
#  'events.csv']

# %% [markdown]
# ## reading flat files

# %% [markdown]
# *the original dataset was split into four separate tables*

# %%
games = pandas.read_csv("data/olympics/games.csv")
events = pandas.read_csv("data/olympics/events.csv")
athletes = pandas.read_csv("data/olympics/athletes.csv")
medalists = pandas.read_csv("data/olympics/medalist.csv")

# %%
games.head()
# Out:
#    id_games        Games  Year  Season       City
# 0         0  1896 Summer  1896  Summer     Athina
# 1         1  1900 Summer  1900  Summer      Paris
# 2         2  1904 Summer  1904  Summer  St. Louis
# 3         3  1906 Summer  1906  Summer     Athina
# 4         4  1908 Summer  1908  Summer     London

# %%
events.head()
# Out:
#    id_event        Games      Sport                                Event  \
# 0         0  1896 Summer  Athletics            Athletics Men's High Jump
# 1         1  1896 Summer  Athletics           Athletics Men's 100 metres
# 2         2  1896 Summer     Tennis                 Tennis Men's Singles
# 3         3  1896 Summer    Cycling  Cycling Men's 333 metres Time Trial
# 4         4  1896 Summer     Tennis                 Tennis Men's Doubles
#
#    id_games
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %%
medalists.head()
# Out:
#    athlete_id  id_event   Medal
# 0       35698         4  Bronze
# 1       12929         4    Gold
# 2      101352         4  Bronze
# 3      121713         4    Gold
# 4       18785         4  Silver

# %% [markdown]
# ## SELECT columns

# %% [markdown]
# `select columns from games`

# %% [markdown]
# *we use* `head` *to see only the top rows of the dataframe*

# %%
games.head()
# Out:
#    id_games        Games  Year  Season       City
# 0         0  1896 Summer  1896  Summer     Athina
# 1         1  1900 Summer  1900  Summer      Paris
# 2         2  1904 Summer  1904  Summer  St. Louis
# 3         3  1906 Summer  1906  Summer     Athina
# 4         4  1908 Summer  1908  Summer     London

# %%
games.head()[["id_games", "Games"]]
# Out:
#    id_games        Games
# 0         0  1896 Summer
# 1         1  1900 Summer
# 2         2  1904 Summer
# 3         3  1906 Summer
# 4         4  1908 Summer

# %%
games.head().get(["id_games", "Games"])
# Out:
#    id_games        Games
# 0         0  1896 Summer
# 1         1  1900 Summer
# 2         2  1904 Summer
# 3         3  1906 Summer
# 4         4  1908 Summer

# %% [markdown]
# *Error handling: the get method doesn't return an error when the column names are wrong*

# %%
# games.head()[["id_games", "Game"]]

# %%
# games.head().get(["id_games", "Game"])

# %% [markdown]
# ## SELECT columns by pattern

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %% [markdown]
# *Remember how to access the column names*

# %%
athletes.columns
# Out:
# Index(['id_athlete', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'NOC',
#        'id_event', 'id_games'],
#       dtype='object')

# %% [markdown]
# *selecting columns that match certain pattern is easy in python*

# %%
column_pattern = [column for column in athletes.columns if 'id' in column]
column_pattern
# Out:
# ['id_athlete', 'id_event', 'id_games']

# %%
athletes.get(column_pattern).head(10)
# Out:
#    id_athlete  id_event  id_games
# 0           1      3723        37
# 1           2      5676        48
# 2           3       671         6
# 3           4       127         1
# 4           5      3593        36
# 5           5      3924        38
# 6           5      3958        39
# 7           6      3922        38
# 8           6      3963        39
# 9           7      3922        38

# %% [markdown]
# *select column by type*

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %%
athletes.select_dtypes("float").head()
# Out:
#     Age  Height  Weight
# 0  24.0   180.0    80.0
# 1  23.0   170.0    60.0
# 2  24.0     NaN     NaN
# 3  34.0     NaN     NaN
# 4  21.0   185.0    82.0

# %% [markdown]
# *combined column selection*

# %%
df_measures = athletes.select_dtypes("float").head()
df_measures.columns
# Out:
# Index(['Age', 'Height', 'Weight'], dtype='object')

# %% [markdown]
# *we can make a list of columns that match certain criteria and then use that list to filter the dataframe*

# %%
total_columns = ["id_athlete"] + list(df_measures.columns)
total_columns
# Out:
# ['id_athlete', 'Age', 'Height', 'Weight']

# %%
athletes.get(total_columns).head()
# Out:
#    id_athlete   Age  Height  Weight
# 0           1  24.0   180.0    80.0
# 1           2  23.0   170.0    60.0
# 2           3  24.0     NaN     NaN
# 3           4  34.0     NaN     NaN
# 4           5  21.0   185.0    82.0

# %% [markdown]
# ## JOINS
#
# `
# select a.columns, b.columns
# from  a left join b
# on a.key = b.key`

# %%
athletes.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games
# 0      3723        37
# 1      5676        48
# 2       671         6
# 3       127         1
# 4      3593        36

# %% [markdown]
# *When making joins always check the number or rows before and after (mostly with left joins)*

# %%
len(athletes)
# Out:
# 187452

# %%
events.head()
# Out:
#    id_event        Games      Sport                                Event  \
# 0         0  1896 Summer  Athletics            Athletics Men's High Jump
# 1         1  1896 Summer  Athletics           Athletics Men's 100 metres
# 2         2  1896 Summer     Tennis                 Tennis Men's Singles
# 3         3  1896 Summer    Cycling  Cycling Men's 333 metres Time Trial
# 4         4  1896 Summer     Tennis                 Tennis Men's Doubles
#
#    id_games
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
pandas.merge(athletes, events, on =["id_event"], how = "left").head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games_x        Games          Sport  \
# 0      3723          37  1992 Summer     Basketball
# 1      5676          48  2012 Summer           Judo
# 2       671           6  1920 Summer       Football
# 3       127           1  1900 Summer     Tug-Of-War
# 4      3593          36  1988 Winter  Speed Skating
#
#                               Event  id_games_y
# 0       Basketball Men's Basketball          37
# 1      Judo Men's Extra-Lightweight          48
# 2           Football Men's Football           6
# 3       Tug-Of-War Men's Tug-Of-War           1
# 4  Speed Skating Women's 500 metres          36

# %% [markdown]
# *when there are repeated column names on the merged dataframes each column gets a suffix (_x and _y by default)*

# %% [markdown]
# ### join athletes with events and games

# %%
athletes_by_event = pandas.merge(athletes, events, on =["id_event", "id_games"], how = "left")

# %%
len(athletes), len(athletes_by_event)
# Out:
# (187452, 187452)

# %%
athletes_by_event.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games        Games          Sport  \
# 0      3723        37  1992 Summer     Basketball
# 1      5676        48  2012 Summer           Judo
# 2       671         6  1920 Summer       Football
# 3       127         1  1900 Summer     Tug-Of-War
# 4      3593        36  1988 Winter  Speed Skating
#
#                               Event
# 0       Basketball Men's Basketball
# 1      Judo Men's Extra-Lightweight
# 2           Football Men's Football
# 3       Tug-Of-War Men's Tug-Of-War
# 4  Speed Skating Women's 500 metres

# %%
len(athletes_by_event)
# Out:
# 187452

# %% [markdown]
# *when doing left joins check the number of rows before and after. if the are not the same there may be some duplicate keys on one of the dataframes*

# %% [markdown]
# ### join with games table

# %%
games.head()
# Out:
#    id_games        Games  Year  Season       City
# 0         0  1896 Summer  1896  Summer     Athina
# 1         1  1900 Summer  1900  Summer      Paris
# 2         2  1904 Summer  1904  Summer  St. Louis
# 3         3  1906 Summer  1906  Summer     Athina
# 4         4  1908 Summer  1908  Summer     London

# %%
athletes_event_games = pandas.merge(athletes_by_event, 
                                    games[["id_games", "Year", "Season", "City"]], 
                                    how = "left", 
                                    on =["id_games"])

# %%
athletes_event_games.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games        Games          Sport  \
# 0      3723        37  1992 Summer     Basketball
# 1      5676        48  2012 Summer           Judo
# 2       671         6  1920 Summer       Football
# 3       127         1  1900 Summer     Tug-Of-War
# 4      3593        36  1988 Winter  Speed Skating
#
#                               Event  Year  Season       City
# 0       Basketball Men's Basketball  1992  Summer  Barcelona
# 1      Judo Men's Extra-Lightweight  2012  Summer     London
# 2           Football Men's Football  1920  Summer  Antwerpen
# 3       Tug-Of-War Men's Tug-Of-War  1900  Summer      Paris
# 4  Speed Skating Women's 500 metres  1988  Winter    Calgary

# %%
len(athletes_by_event), len(athletes_event_games)
# Out:
# (187452, 187452)

# %% [markdown]
# ### join with medalists table

# %%
medalists.head()
# Out:
#    athlete_id  id_event   Medal
# 0       35698         4  Bronze
# 1       12929         4    Gold
# 2      101352         4  Bronze
# 3      121713         4    Gold
# 4       18785         4  Silver

# %%
full_dataset = pandas.merge(athletes_event_games, medalists, 
                             left_on = ["id_athlete", "id_event"],
                             right_on = ["athlete_id", "id_event"],
                             how = "left")

# %%
len(athletes_event_games), len(full_dataset)
# Out:
# (187452, 187452)

# %%
full_dataset.head()
# Out:
#    id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 0           1                 A Dijiang   M  24.0   180.0    80.0  CHN
# 1           2                  A Lamusi   M  23.0   170.0    60.0  CHN
# 2           3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN
# 3           4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 4           5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED
#
#    id_event  id_games        Games          Sport  \
# 0      3723        37  1992 Summer     Basketball
# 1      5676        48  2012 Summer           Judo
# 2       671         6  1920 Summer       Football
# 3       127         1  1900 Summer     Tug-Of-War
# 4      3593        36  1988 Winter  Speed Skating
#
#                               Event  Year  Season       City  athlete_id Medal
# 0       Basketball Men's Basketball  1992  Summer  Barcelona         NaN   NaN
# 1      Judo Men's Extra-Lightweight  2012  Summer     London         NaN   NaN
# 2           Football Men's Football  1920  Summer  Antwerpen         NaN   NaN
# 3       Tug-Of-War Men's Tug-Of-War  1900  Summer      Paris         4.0  Gold
# 4  Speed Skating Women's 500 metres  1988  Winter    Calgary         NaN   NaN

# %% [markdown]
# *Checking if the join was done correctly: Are there some medalists on the table?*

# %%
full_dataset.loc[~full_dataset["Medal"].isnull()].head()
# Out:
#     id_athlete                      Name Sex   Age  Height  Weight  NOC  \
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN
# 20          15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN  FIN
# 22          16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  FIN
# 23          17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  FIN
# 28          20        Kjetil Andr Aamodt   M  22.0   176.0    85.0  NOR
#
#     id_event  id_games        Games          Sport  \
# 3        127         1  1900 Summer     Tug-Of-War
# 20       672         6  1920 Summer       Swimming
# 22      5800        49  2014 Winter     Ice Hockey
# 23      1347        15  1948 Summer     Gymnastics
# 28      3993        39  1994 Winter  Alpine Skiing
#
#                                      Event  Year  Season         City  \
# 3              Tug-Of-War Men's Tug-Of-War  1900  Summer        Paris
# 20  Swimming Men's 200 metres Breaststroke  1920  Summer    Antwerpen
# 22             Ice Hockey Men's Ice Hockey  2014  Winter        Sochi
# 23  Gymnastics Men's Individual All-Around  1948  Summer       London
# 28            Alpine Skiing Men's Downhill  1994  Winter  Lillehammer
#
#     athlete_id   Medal
# 3          4.0    Gold
# 20        15.0  Bronze
# 22        16.0  Bronze
# 23        17.0  Bronze
# 28        20.0  Silver

# %% [markdown]
# *Since the dataset is joined, we remove the id columns*

# %%
column_pattern = [column for column in full_dataset.columns if 'id' not in column]
full_dataset = full_dataset[column_pattern]

# %%
full_dataset.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Year  Season       City  \
# 0     Basketball       Basketball Men's Basketball  1992  Summer  Barcelona
# 1           Judo      Judo Men's Extra-Lightweight  2012  Summer     London
# 2       Football           Football Men's Football  1920  Summer  Antwerpen
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  1900  Summer      Paris
# 4  Speed Skating  Speed Skating Women's 500 metres  1988  Winter    Calgary
#
#   Medal
# 0   NaN
# 1   NaN
# 2   NaN
# 3  Gold
# 4   NaN

# %% [markdown]
# ## NVL
# `select nvl(column, value_to_fill) from table`

# %%
full_dataset["Medal"] = full_dataset["Medal"].fillna("No Medal")

# %%
full_dataset.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Year  Season       City  \
# 0     Basketball       Basketball Men's Basketball  1992  Summer  Barcelona
# 1           Judo      Judo Men's Extra-Lightweight  2012  Summer     London
# 2       Football           Football Men's Football  1920  Summer  Antwerpen
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  1900  Summer      Paris
# 4  Speed Skating  Speed Skating Women's 500 metres  1988  Winter    Calgary
#
#       Medal
# 0  No Medal
# 1  No Medal
# 2  No Medal
# 3      Gold
# 4  No Medal

# %% [markdown]
# ## SELECT WHERE
#
# `select columns where condition`

# %% [markdown]
# *Chinese athletes*

# %%
df_chinese = full_dataset.loc[full_dataset["NOC"] == "CHN"]

# %%
df_chinese.head()
# Out:
#                Name Sex   Age  Height  Weight  NOC        Games       Sport  \
# 0         A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer  Basketball
# 1          A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer        Judo
# 802   Abudoureheman   M  22.0   182.0    75.0  CHN  2000 Summer      Boxing
# 1950      Ai Linuer   M  25.0   160.0    62.0  CHN  2004 Summer   Wrestling
# 1951      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016 Summer    Swimming
#
#                                          Event  Year  Season            City  \
# 0                  Basketball Men's Basketball  1992  Summer       Barcelona
# 1                 Judo Men's Extra-Lightweight  2012  Summer          London
# 802                  Boxing Men's Middleweight  2000  Summer          Sydney
# 1950  Wrestling Men's Lightweight, Greco-Roman  2004  Summer          Athina
# 1951     Swimming Women's 200 metres Freestyle  2016  Summer  Rio de Janeiro
#
#          Medal
# 0     No Medal
# 1     No Medal
# 802   No Medal
# 1950  No Medal
# 1951  No Medal

# %% [markdown]
# *in which game did the chinese had more athletes?*

# %%
df_chinese = df_chinese.get(["Games", "Name"]).drop_duplicates()
df_chinese.head()
# Out:
#             Games           Name
# 0     1992 Summer      A Dijiang
# 1     2012 Summer       A Lamusi
# 802   2000 Summer  Abudoureheman
# 1950  2004 Summer      Ai Linuer
# 1951  2016 Summer      Ai Yanhan

# %%
df_chinese = df_chinese.groupby("Games", as_index = False).count()
df_chinese.head()
# Out:
#          Games  Name
# 0  1932 Summer     1
# 1  1936 Summer    54
# 2  1948 Summer    31
# 3  1952 Summer     1
# 4  1980 Winter    24

# %%
df_chinese.sort_values(by = "Name", ascending = False).head()
# Out:
#           Games  Name
# 18  2008 Summer   583
# 22  2016 Summer   390
# 16  2004 Summer   372
# 20  2012 Summer   365
# 12  1996 Summer   289

# %% [markdown]
# `select column where column like '%pattern %'`

# %% [markdown]
# *Winklevoss twins*

# %%
full_dataset.loc[full_dataset["Name"].str.contains("Winklevoss")]
# Out:
#                              Name Sex   Age  Height  Weight  NOC        Games  \
# 181082  Cameron Howard Winklevoss   M  26.0   196.0    96.0  USA  2008 Summer
# 181083    Tyler Howard Winklevoss   M  26.0   196.0    95.0  USA  2008 Summer
#
#          Sport                       Event  Year  Season     City     Medal
# 181082  Rowing  Rowing Men's Coxless Pairs  2008  Summer  Beijing  No Medal
# 181083  Rowing  Rowing Men's Coxless Pairs  2008  Summer  Beijing  No Medal

# %% [markdown]
# *my cousins*

# %% [markdown]
# *when checking name patterns we're using the lower() method to avoid missing records by capitalization*

# %%
full_dataset.loc[full_dataset["Name"].str.lower().str.contains("montoya")].head()
# Out:
#                              Name Sex   Age  Height  Weight  NOC        Games  \
# 65447   Sergio Luis Henao Montoya   M  24.0   170.0    61.0  COL  2012 Summer
# 65448   Sergio Luis Henao Montoya   M  28.0   170.0    61.0  COL  2016 Summer
# 66223     Armando Herrera Montoya   M  24.0   170.0    69.0  MEX  1960 Summer
# 66224     Armando Herrera Montoya   M  28.0   170.0    69.0  MEX  1964 Summer
# 92573  Jos Luis Laverdeza Montoya   M  19.0   167.0    67.0  CUB  1980 Summer
#
#             Sport                                Event  Year  Season  \
# 65447     Cycling  Cycling Men's Road Race, Individual  2012  Summer
# 65448     Cycling  Cycling Men's Road Race, Individual  2016  Summer
# 66223  Basketball          Basketball Men's Basketball  1960  Summer
# 66224  Basketball          Basketball Men's Basketball  1964  Summer
# 92573     Fencing      Fencing Men's Sabre, Individual  1980  Summer
#
#                  City     Medal
# 65447          London  No Medal
# 65448  Rio de Janeiro  No Medal
# 66223            Roma  No Medal
# 66224           Tokyo  No Medal
# 92573          Moskva  No Medal

# %% [markdown]
# *female peruvian athletes*

# %%
full_dataset.loc[(full_dataset["NOC"] == "PER") & (full_dataset["Sex"] == "F")]
# Out:
#                                              Name Sex   Age  Height  Weight  \
# 2047                           Fiorella Ata Junek   F  23.0   170.0    65.0
# 6840                  Wilma Yanet Arizapana Yucra   F  29.0   164.0    54.0
# 7379                           Olga Asato Hichiva   F  19.0   166.0    65.0
# 8418                               Mara Pia Ayora   F  18.0   178.0    68.0
# 9728    E. Gladys Baldwin Lopez (-de Seminario-)    F  31.0   167.0    67.0
# ...                                           ...  ..   ...     ...     ...
# 173780                      Norma Velarde Alvarez   F  21.0   169.0    74.0
# 173796           Claudia Silvana Velsquez Ponzoni   F  16.0     NaN     NaN
# 174952                    Mara Luisa Vilca Alzola   F  24.0   164.0    58.0
# 185060                 Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0
# 185061                 Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0
#
#         NOC        Games       Sport  \
# 2047    PER  2000 Summer  Volleyball
# 6840    PER  2012 Summer   Athletics
# 7379    PER  1968 Summer  Volleyball
# 8418    PER  1980 Summer    Swimming
# 9728    PER  1968 Summer    Shooting
# ...     ...          ...         ...
# 173780  PER  1968 Summer  Volleyball
# 173796  PER  1992 Summer    Swimming
# 174952  PER  1972 Summer   Athletics
# 185060  PER  1996 Summer  Volleyball
# 185061  PER  2000 Summer  Volleyball
#
#                                                     Event  Year  Season  \
# 2047                        Volleyball Women's Volleyball  2000  Summer
# 6840                           Athletics Women's Marathon  2012  Summer
# 7379                        Volleyball Women's Volleyball  1968  Summer
# 8418                Swimming Women's 400 metres Freestyle  1980  Summer
# 9728    Shooting Mixed Small-Bore Rifle, Prone, 50 metres  1968  Summer
# ...                                                   ...   ...     ...
# 173780                      Volleyball Women's Volleyball  1968  Summer
# 173796           Swimming Women's 100 metres Breaststroke  1992  Summer
# 174952                       Athletics Women's 100 metres  1972  Summer
# 185060                      Volleyball Women's Volleyball  1996  Summer
# 185061                      Volleyball Women's Volleyball  2000  Summer
#
#                City     Medal
# 2047         Sydney  No Medal
# 6840         London  No Medal
# 7379    Mexico City  No Medal
# 8418         Moskva  No Medal
# 9728    Mexico City  No Medal
# ...             ...       ...
# 173780  Mexico City  No Medal
# 173796    Barcelona  No Medal
# 174952       Munich  No Medal
# 185060      Atlanta  No Medal
# 185061       Sydney  No Medal
#
# [136 rows x 13 columns]

# %% [markdown]
# *peruvian medalists*

# %%
full_dataset.loc[(full_dataset["Medal"] != "No Medal") & (full_dataset["NOC"] == "PER")]
# Out:
#                                                    Name Sex   Age  Height  \
# 19608                              Francisco Boza Dibos   M  19.0   176.0
# 26619                      Luisa Haydee Cervera Cevedon   F  24.0   173.0
# 35983                            Alejandra de la Guerra   F  20.0   173.0
# 46458                             Denisse Fajardo Garca   F  24.0   171.0
# 52523                                   Miriam Gallardo   F  20.0   168.0
# 53348                          Rosa Gisella Garca Rivas   F  24.0   175.0
# 55442                        Juan Jorge Giha Yarur, Jr.   M  37.0   171.0
# 65911                              Sonia Isabel Heredia   F  24.0   175.0
# 68832                           Katherine "Kathy" Horny   F  18.0   186.0
# 101870                         Natalia Mara Mlaga Dibos   F  24.0   170.0
# 128653  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0   194.0
# 162855                   Cecilia Roxana Tait Villacorta   F  26.0   182.0
# 167621                                   Gina Torrealva   F  26.0   175.0
# 170777                  Cenaida Cebastiana Uribe Medina   F  22.0   174.0
# 173457                         Edwin Gonzalo Vsquez Cam   M  25.0     NaN
#
#         Weight  NOC        Games       Sport  \
# 19608     95.0  PER  1984 Summer    Shooting
# 26619     70.0  PER  1988 Summer  Volleyball
# 35983     59.0  PER  1988 Summer  Volleyball
# 46458     62.0  PER  1988 Summer  Volleyball
# 52523     57.0  PER  1988 Summer  Volleyball
# 53348     69.0  PER  1988 Summer  Volleyball
# 55442     94.0  PER  1992 Summer    Shooting
# 65911     69.0  PER  1988 Summer  Volleyball
# 68832     76.0  PER  1988 Summer  Volleyball
# 101870    59.0  PER  1988 Summer  Volleyball
# 128653    72.0  PER  1988 Summer  Volleyball
# 162855    70.0  PER  1988 Summer  Volleyball
# 167621    59.0  PER  1988 Summer  Volleyball
# 170777    65.0  PER  1988 Summer  Volleyball
# 173457     NaN  PER  1948 Summer    Shooting
#
#                                         Event  Year  Season         City  \
# 19608                     Shooting Mixed Trap  1984  Summer  Los Angeles
# 26619           Volleyball Women's Volleyball  1988  Summer        Seoul
# 35983           Volleyball Women's Volleyball  1988  Summer        Seoul
# 46458           Volleyball Women's Volleyball  1988  Summer        Seoul
# 52523           Volleyball Women's Volleyball  1988  Summer        Seoul
# 53348           Volleyball Women's Volleyball  1988  Summer        Seoul
# 55442                    Shooting Mixed Skeet  1992  Summer    Barcelona
# 65911           Volleyball Women's Volleyball  1988  Summer        Seoul
# 68832           Volleyball Women's Volleyball  1988  Summer        Seoul
# 101870          Volleyball Women's Volleyball  1988  Summer        Seoul
# 128653          Volleyball Women's Volleyball  1988  Summer        Seoul
# 162855          Volleyball Women's Volleyball  1988  Summer        Seoul
# 167621          Volleyball Women's Volleyball  1988  Summer        Seoul
# 170777          Volleyball Women's Volleyball  1988  Summer        Seoul
# 173457  Shooting Men's Free Pistol, 50 metres  1948  Summer       London
#
#          Medal
# 19608   Silver
# 26619   Silver
# 35983   Silver
# 46458   Silver
# 52523   Silver
# 53348   Silver
# 55442   Silver
# 65911   Silver
# 68832   Silver
# 101870  Silver
# 128653  Silver
# 162855  Silver
# 167621  Silver
# 170777  Silver
# 173457    Gold

# %% [markdown]
# *peruvian gold medalists*

# %%
full_dataset.loc[(full_dataset["Medal"] == "Gold") & (full_dataset["NOC"] == "PER")]
# Out:
#                             Name Sex   Age  Height  Weight  NOC        Games  \
# 173457  Edwin Gonzalo Vsquez Cam   M  25.0     NaN     NaN  PER  1948 Summer
#
#            Sport                                  Event  Year  Season    City  \
# 173457  Shooting  Shooting Men's Free Pistol, 50 metres  1948  Summer  London
#
#        Medal
# 173457  Gold

# %% [markdown]
# *most appearances by a peruvian female*

# %%
athletes_female_peruvian = full_dataset.loc[(full_dataset["NOC"] == "PER") & (full_dataset["Sex"] == "F")]

# %%
athletes_female_peruvian.get(["Name", "Games"])\
                        .groupby("Name", as_index = False).count()\
                        .sort_values("Games", ascending = False)
# Out:
#                               Name  Games
# 71        Natalia Mara Mlaga Dibos      4
# 11  Cecilia Roxana Tait Villacorta      3
# 82         Santa Ins Melchor Huiza      3
# 50          Mara Cecilia del Risco      3
# 79        Rosa Gisella Garca Rivas      3
# ..                             ...    ...
# 39              Kimberly Garca Len      1
# 38         Katherine "Kathy" Horny      1
# 37                   Karin Brandes      1
# 36                   Karen Horning      1
# 47                   Magaly Montes      1
#
# [95 rows x 2 columns]

# %% [markdown]
# *Natalia Málaga appearances*

# %%
full_dataset.loc[full_dataset["Name"] == "Natalia Mara Mlaga Dibos"]
# Out:
#                             Name Sex   Age  Height  Weight  NOC        Games  \
# 101868  Natalia Mara Mlaga Dibos   F  16.0   170.0    59.0  PER  1980 Summer
# 101869  Natalia Mara Mlaga Dibos   F  20.0   170.0    59.0  PER  1984 Summer
# 101870  Natalia Mara Mlaga Dibos   F  24.0   170.0    59.0  PER  1988 Summer
# 101871  Natalia Mara Mlaga Dibos   F  36.0   170.0    59.0  PER  2000 Summer
#
#              Sport                          Event  Year  Season         City  \
# 101868  Volleyball  Volleyball Women's Volleyball  1980  Summer       Moskva
# 101869  Volleyball  Volleyball Women's Volleyball  1984  Summer  Los Angeles
# 101870  Volleyball  Volleyball Women's Volleyball  1988  Summer        Seoul
# 101871  Volleyball  Volleyball Women's Volleyball  2000  Summer       Sydney
#
#            Medal
# 101868  No Medal
# 101869  No Medal
# 101870    Silver
# 101871  No Medal

# %% [markdown]
# *Seul 88 peruvian volleyball team*

# %%
full_dataset.loc[(full_dataset["NOC"] == "PER") &
                 (full_dataset["Sex"] == "F") &
                 (full_dataset["Sport"] == "Volleyball") &
                 (full_dataset["Games"] == "1988 Summer")]
# Out:
#                                                    Name Sex   Age  Height  \
# 26619                      Luisa Haydee Cervera Cevedon   F  24.0   173.0
# 35983                            Alejandra de la Guerra   F  20.0   173.0
# 46458                             Denisse Fajardo Garca   F  24.0   171.0
# 52523                                   Miriam Gallardo   F  20.0   168.0
# 53348                          Rosa Gisella Garca Rivas   F  24.0   175.0
# 65911                              Sonia Isabel Heredia   F  24.0   175.0
# 68832                           Katherine "Kathy" Horny   F  18.0   186.0
# 101870                         Natalia Mara Mlaga Dibos   F  24.0   170.0
# 128653  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0   194.0
# 162855                   Cecilia Roxana Tait Villacorta   F  26.0   182.0
# 167621                                   Gina Torrealva   F  26.0   175.0
# 170777                  Cenaida Cebastiana Uribe Medina   F  22.0   174.0
#
#         Weight  NOC        Games       Sport                          Event  \
# 26619     70.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 35983     59.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 46458     62.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 52523     57.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 53348     69.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 65911     69.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 68832     76.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 101870    59.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 128653    72.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 162855    70.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 167621    59.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
# 170777    65.0  PER  1988 Summer  Volleyball  Volleyball Women's Volleyball
#
#         Year  Season   City   Medal
# 26619   1988  Summer  Seoul  Silver
# 35983   1988  Summer  Seoul  Silver
# 46458   1988  Summer  Seoul  Silver
# 52523   1988  Summer  Seoul  Silver
# 53348   1988  Summer  Seoul  Silver
# 65911   1988  Summer  Seoul  Silver
# 68832   1988  Summer  Seoul  Silver
# 101870  1988  Summer  Seoul  Silver
# 128653  1988  Summer  Seoul  Silver
# 162855  1988  Summer  Seoul  Silver
# 167621  1988  Summer  Seoul  Silver
# 170777  1988  Summer  Seoul  Silver

# %% [markdown]
# <img src = "https://as.com/ascolor/imagenes/2018/04/12/reportajes/1523555668_744838_1590078378_noticiareportajes_grande.jpg">

# %% [markdown]
# **["Spasibo", Perú: 30 años de la plata olímpica en voleibol](https://as.com/ascolor/2018/04/12/reportajes/1523555668_744838.html)**

# %% [markdown]
# https://www.youtube.com/watch?v=EeCLxuvenjs

# %% [markdown]
# ## SELECT DISTINCT

# %% [markdown]
# `select distinct column from table`

# %%
full_dataset.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Year  Season       City  \
# 0     Basketball       Basketball Men's Basketball  1992  Summer  Barcelona
# 1           Judo      Judo Men's Extra-Lightweight  2012  Summer     London
# 2       Football           Football Men's Football  1920  Summer  Antwerpen
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  1900  Summer      Paris
# 4  Speed Skating  Speed Skating Women's 500 metres  1988  Winter    Calgary
#
#       Medal
# 0  No Medal
# 1  No Medal
# 2  No Medal
# 3      Gold
# 4  No Medal

# %% [markdown]
# *get a collection of unique cities*

# %%
full_dataset["City"].unique()
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %% [markdown]
# *how many there are?*

# %%
full_dataset["City"].nunique()
# Out:
# 42

# %% [markdown]
# *getting a dataframe of the unique cities*

# %%
full_dataset[["City"]].drop_duplicates().head()
# Out:
#         City
# 0  Barcelona
# 1     London
# 2  Antwerpen
# 3      Paris
# 4    Calgary

# %% [markdown]
# ## GROUP BY COUNT

# %% [markdown]
# `select column, count()
# from table
# group by column`

# %%
full_dataset.get(["City", "Games"])\
            .drop_duplicates()\
            .groupby("City")\
            .count()\
            .head()
# Out:
#              Games
# City
# Albertville      1
# Amsterdam        1
# Antwerpen        1
# Athina           3
# Atlanta          1

# %%
df_counts = full_dataset.get(["City", "Games"])\
                        .drop_duplicates()\
                        .groupby("City")\
                        .count()\

df_counts.sort_values(by = "Games", ascending = False).head(10)
# Out:
#                 Games
# City
# Athina              3
# London              3
# Paris               2
# Los Angeles         2
# Lake Placid         2
# Innsbruck           2
# Sankt Moritz        2
# Albertville         1
# Sapporo             1
# Rio de Janeiro      1

# %%
full_dataset[["City", "Games"]].drop_duplicates()["City"].value_counts()
# Out:
# London                    3
# Athina                    3
# Sankt Moritz              2
# Paris                     2
# Lake Placid               2
# Los Angeles               2
# Innsbruck                 2
# Sarajevo                  1
# Antwerpen                 1
# Amsterdam                 1
# Roma                      1
# Garmisch-Partenkirchen    1
# Squaw Valley              1
# Nagano                    1
# Calgary                   1
# Montreal                  1
# Vancouver                 1
# Mexico City               1
# Helsinki                  1
# Albertville               1
# Lillehammer               1
# Sapporo                   1
# St. Louis                 1
# Grenoble                  1
# Chamonix                  1
# Rio de Janeiro            1
# Berlin                    1
# Munich                    1
# Beijing                   1
# Oslo                      1
# Stockholm                 1
# Salt Lake City            1
# Cortina d'Ampezzo         1
# Melbourne                 1
# Torino                    1
# Sydney                    1
# Seoul                     1
# Barcelona                 1
# Sochi                     1
# Moskva                    1
# Atlanta                   1
# Tokyo                     1
# Name: City, dtype: int64

# %%
games.loc[games["City"] == "London"]
# Out:
#     id_games        Games  Year  Season    City
# 4          4  1908 Summer  1908  Summer  London
# 15        15  1948 Summer  1948  Summer  London
# 48        48  2012 Summer  2012  Summer  London

# %% [markdown]
# ## Union

# %%
split1 = full_dataset.loc[full_dataset["Games"] < "2016 Summer"]
split2 = full_dataset.loc[full_dataset["Games"] == "2016 Summer"]

# %%
os.listdir("data/olympics/")
# Out:
# ['split2.csv',
#  'split1.csv',
#  '.DS_Store',
#  'athletes.csv',
#  'medalist.csv',
#  'games.csv',
#  'athlete_events.csv',
#  'events.csv']

# %%
df_split_1 = pandas.read_csv("data/olympics/split1.csv")
df_split_2 = pandas.read_csv("data/olympics/split2.csv")

# %%
df_split_1.head()
# Out:
#                        Name Sex   Age  Height  Weight  NOC        Games  \
# 0                 A Dijiang   M  24.0   180.0    80.0  CHN  1992 Summer
# 1                  A Lamusi   M  23.0   170.0    60.0  CHN  2012 Summer
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN  DEN  1920 Summer
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  DEN  1900 Summer
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0  NED  1988 Winter
#
#            Sport                             Event  Year  Season       City  \
# 0     Basketball       Basketball Men's Basketball  1992  Summer  Barcelona
# 1           Judo      Judo Men's Extra-Lightweight  2012  Summer     London
# 2       Football           Football Men's Football  1920  Summer  Antwerpen
# 3     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  1900  Summer      Paris
# 4  Speed Skating  Speed Skating Women's 500 metres  1988  Winter    Calgary
#
#       Medal
# 0  No Medal
# 1  No Medal
# 2  No Medal
# 3      Gold
# 4  No Medal

# %%
df_split_1["Year"].min(), df_split_1["Year"].max()
# Out:
# (1896, 2014)

# %%
df_split_2.head()
# Out:
#                   Name Sex   Age  Height  Weight  NOC        Games  \
# 0        Andreea Aanei   F  22.0   170.0   125.0  ROU  2016 Summer
# 1    Nstor Abad Sanjun   M  23.0   167.0    64.0  ESP  2016 Summer
# 2  Antonio Abadia Beci   M  26.0   170.0    65.0  ESP  2016 Summer
# 3    Giovanni Abagnale   M  21.0   198.0    90.0  ITA  2016 Summer
# 4    Patimat Abakarova   F  21.0   165.0    49.0  AZE  2016 Summer
#
#            Sport                                    Event  Year  Season  \
# 0  Weightlifting  Weightlifting Women's Super-Heavyweight  2016  Summer
# 1     Gymnastics   Gymnastics Men's Individual All-Around  2016  Summer
# 2      Athletics             Athletics Men's 5,000 metres  2016  Summer
# 3         Rowing               Rowing Men's Coxless Pairs  2016  Summer
# 4      Taekwondo              Taekwondo Women's Flyweight  2016  Summer
#
#              City     Medal
# 0  Rio de Janeiro  No Medal
# 1  Rio de Janeiro  No Medal
# 2  Rio de Janeiro  No Medal
# 3  Rio de Janeiro    Bronze
# 4  Rio de Janeiro    Bronze

# %%
df_split_2["Year"].min(), df_split_2["Year"].max()
# Out:
# (2016, 2016)

# %%
len(df_split_1), len(df_split_2)
# Out:
# (176273, 11179)

# %% [markdown]
# *since both dataframes have the same columns we can append one to the other*

# %%
df_total = pandas.concat([df_split_1, df_split_2])

# %%
len(df_total)
# Out:
# 187452

# %%
len(df_total.append(df_split_2))
# Out:
# 198631

# %% [markdown]
# # Contact

# %% [markdown]
# Manuel Montoya
# * Mail: manuel.montoya@pucp.edu.pe
# * Linkedin: https://www.linkedin.com/in/manuel-montoya-gamio/
